# %%
import os
import shutil
import json
from itertools import islice

# List of directories containing the raw files
paths = ["2018", "2019", "2020", "2021", "2022", "2023"]

# Destination base directory to store files with .json extension
destination_base = "JsonFile"

# %%
# Ensure the destination base directory exists
os.makedirs(destination_base, exist_ok=True)

def process_chunk(files):
    results = []
    for file_path, destination_path in files:
        try:
            # Check if the file is a valid JSON
            with open(file_path, 'r') as f:
                json.load(f)  # Validate JSON format
            
            # Add .json extension and move the file
            new_file_name = f"{os.path.basename(file_path)}.json"
            new_file_path = os.path.join(destination_path, new_file_name)
            shutil.copy(file_path, new_file_path)
            results.append(f"Processed: {file_path} -> {new_file_path}")
        except json.JSONDecodeError:
            results.append(f"Skipped (invalid JSON): {file_path}")
    return results

def chunked_iterable(iterable, chunk_size):
    """Yield successive chunks from an iterable."""
    it = iter(iterable)
    while chunk := list(islice(it, chunk_size)):
        yield chunk

# Prepare a list of files to process
tasks = []
for path in paths:
    destination_path = os.path.join(destination_base, path)
    os.makedirs(destination_path, exist_ok=True)

    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        tasks.append((file_path, destination_path))

# Process files in chunks
chunk_size = 100  # Adjust chunk size based on memory and performance
for chunk in chunked_iterable(tasks, chunk_size):
    results = process_chunk(chunk)
    for result in results:
        print(result)
# Out:
# Processed: 2021\202100000 -> JsonFile\2021\202100000.json
# Processed: 2021\202100001 -> JsonFile\2021\202100001.json
# Processed: 2021\202100002 -> JsonFile\2021\202100002.json
# Processed: 2021\202100003 -> JsonFile\2021\202100003.json
# Processed: 2021\202100004 -> JsonFile\2021\202100004.json
# Processed: 2021\202100005 -> JsonFile\2021\202100005.json
# Processed: 2021\202100006 -> JsonFile\2021\202100006.json
# Processed: 2021\202100007 -> JsonFile\2021\202100007.json
# Processed: 2021\202100008 -> JsonFile\2021\202100008.json
# Processed: 2021\202100009 -> JsonFile\2021\202100009.json
# Processed: 2021\202100010 -> JsonFile\2021\202100010.json
# Processed: 2021\202100011 -> JsonFile\2021\202100011.json
# Processed: 2021\202100012 -> JsonFile\2021\202100012.json
# Processed: 2021\202100013 -> JsonFile\2021\202100013.json
# Processed: 2021\202100014 -> JsonFile\2021\202100014.json
# Processed: 2021\202100015 -> JsonFile\2021\202100015.json
# Processed: 2021\202100016 -> JsonFile\2021\202100016.json
# Processed: 2021\202100017 -> JsonFile\2021\202100017.json
# Processed: 2021\202100018 -> JsonFile\2021\202100018.json
# Processed: 2021\202100019 -> JsonFile\2021\202100019.json
# Processed: 2021\202100020 -> JsonFile\2021\202100020.json
# Processed: 2021\202100021 -> JsonFile\2021\202100021.json
# Processed: 2021\202100022 -> JsonFile\2021\202100022.json
# Processed: 2021\202100023 -> JsonFile\2021\202100023.json
# Processed: 2021\202100024 -> JsonFile\2021\202100024.json
# Processed: 2021\202100025 -> JsonFile\2021\202100025.json
# Processed: 2021\202100026 -> JsonFile\2021\202100026.json
# Processed: 2021\202100027 -> JsonFile\2021\202100027.json
# Processed: 2021\202100028 -> JsonFile\2021\202100028.json
# Processed: 2021\202100029 -> JsonFile\2021\202100029.json
# Processed: 2021\202100030 -> JsonFile\2021\202100030.json
# Processed: 2021\202100031 -> JsonFile\2021\202100031.json
# Processed: 2021\202100032 -> JsonFile\2021\202100032.json
# Processed: 2021\202100033 -> JsonFile\2021\202100033.json
# Processed: 2021\202100034 -> JsonFile\2021\202100034.json
# Processed: 2021\202100035 -> JsonFile\2021\202100035.json
# Processed: 2021\202100036 -> JsonFile\2021\202100036.json
# Processed: 2021\202100037 -> JsonFile\2021\202100037.json
# Processed: 2021\202100038 -> JsonFile\2021\202100038.json
# Processed: 2021\202100039 -> JsonFile\2021\202100039.json
# Processed: 2021\202100040 -> JsonFile\2021\202100040.json
# Processed: 2021\202100041 -> JsonFile\2021\202100041.json
# Processed: 2021\202100042 -> JsonFile\2021\202100042.json
# Processed: 2021\202100043 -> JsonFile\2021\202100043.json
# Processed: 2021\202100044 -> JsonFile\2021\202100044.json
# Processed: 2021\202100045 -> JsonFile\2021\202100045.json
# Processed: 2021\202100046 -> JsonFile\2021\202100046.json
# Processed: 2021\202100047 -> JsonFile\2021\202100047.json
# Processed: 2021\202100048 -> JsonFile\2021\202100048.json
# Processed: 2021\202100049 -> JsonFile\2021\202100049.json
# Processed: 2021\202100050 -> JsonFile\2021\202100050.json
# Processed: 2021\202100051 -> JsonFile\2021\202100051.json
# Processed: 2021\202100052 -> JsonFile\2021\202100052.json
# Processed: 2021\202100053 -> JsonFile\2021\202100053.json
# Processed: 2021\202100054 -> JsonFile\2021\202100054.json
# Processed: 2021\202100055 -> JsonFile\2021\202100055.json
# Processed: 2021\202100056 -> JsonFile\2021\202100056.json
# Processed: 2021\202100057 -> JsonFile\2021\202100057.json
# Processed: 2021\202100058 -> JsonFile\2021\202100058.json
# Processed: 2021\202100059 -> JsonFile\2021\202100059.json
# Processed: 2021\202100060 -> JsonFile\2021\202100060.json
# Processed: 2021\202100061 -> JsonFile\2021\202100061.json
# Processed: 2021\202100062 -> JsonFile\2021\202100062.json
# Processed: 2021\202100063 -> JsonFile\2021\202100063.json
# Processed: 2021\202100064 -> JsonFile\2021\202100064.json
# Processed: 2021\202100065 -> JsonFile\2021\202100065.json
# Processed: 2021\202100066 -> JsonFile\2021\202100066.json
# Processed: 2021\202100067 -> JsonFile\2021\202100067.json
# Processed: 2021\202100068 -> JsonFile\2021\202100068.json
# Processed: 2021\202100069 -> JsonFile\2021\202100069.json
# Processed: 2021\202100070 -> JsonFile\2021\202100070.json
# Processed: 2021\202100071 -> JsonFile\2021\202100071.json
# Processed: 2021\202100072 -> JsonFile\2021\202100072.json
# Processed: 2021\202100073 -> JsonFile\2021\202100073.json
# Processed: 2021\202100074 -> JsonFile\2021\202100074.json
# Processed: 2021\202100075 -> JsonFile\2021\202100075.json
# Processed: 2021\202100076 -> JsonFile\2021\202100076.json
# Processed: 2021\202100077 -> JsonFile\2021\202100077.json
# Processed: 2021\202100078 -> JsonFile\2021\202100078.json
# Processed: 2021\202100079 -> JsonFile\2021\202100079.json
# Processed: 2021\202100080 -> JsonFile\2021\202100080.json
# Processed: 2021\202100081 -> JsonFile\2021\202100081.json
# Processed: 2021\202100082 -> JsonFile\2021\202100082.json
# Processed: 2021\202100083 -> JsonFile\2021\202100083.json
# Processed: 2021\202100084 -> JsonFile\2021\202100084.json
# Processed: 2021\202100085 -> JsonFile\2021\202100085.json
# Processed: 2021\202100086 -> JsonFile\2021\202100086.json
# Processed: 2021\202100087 -> JsonFile\2021\202100087.json
# Processed: 2021\202100088 -> JsonFile\2021\202100088.json
# Processed: 2021\202100089 -> JsonFile\2021\202100089.json
# Processed: 2021\202100090 -> JsonFile\2021\202100090.json
# Processed: 2021\202100091 -> JsonFile\2021\202100091.json
# Processed: 2021\202100092 -> JsonFile\2021\202100092.json
# Processed: 2021\202100093 -> JsonFile\2021\202100093.json
# Processed: 2021\202100094 -> JsonFile\2021\202100094.json
# Processed: 2021\202100095 -> JsonFile\2021\202100095.json
# Processed: 2021\202100096 -> JsonFile\2021\202100096.json
# Processed: 2021\202100097 -> JsonFile\2021\202100097.json
# Processed: 2021\202100098 -> JsonFile\2021\202100098.json
# Processed: 2021\202100099 -> JsonFile\2021\202100099.json
# Processed: 2021\202100100 -> JsonFile\2021\202100100.json
# Processed: 2021\202100101 -> JsonFile\2021\202100101.json
# Processed: 2021\202100102 -> JsonFile\2021\202100102.json
# Processed: 2021\202100103 -> JsonFile\2021\202100103.json
# Processed: 2021\202100104 -> JsonFile\2021\202100104.json
# Processed: 2021\202100105 -> JsonFile\2021\202100105.json
# Processed: 2021\202100106 -> JsonFile\2021\202100106.json
# Processed: 2021\202100107 -> JsonFile\2021\202100107.json
# Processed: 2021\202100108 -> JsonFile\2021\202100108.json
# Processed: 2021\202100109 -> JsonFile\2021\202100109.json
# Processed: 2021\202100110 -> JsonFile\2021\202100110.json
# Processed: 2021\202100111 -> JsonFile\2021\202100111.json
# Processed: 2021\202100112 -> JsonFile\2021\202100112.json
# Processed: 2021\202100113 -> JsonFile\2021\202100113.json
# Processed: 2021\202100114 -> JsonFile\2021\202100114.json
# Processed: 2021\202100115 -> JsonFile\2021\202100115.json
# Processed: 2021\202100116 -> JsonFile\2021\202100116.json
# Processed: 2021\202100117 -> JsonFile\2021\202100117.json
# Processed: 2021\202100118 -> JsonFile\2021\202100118.json
# Processed: 2021\202100119 -> JsonFile\2021\202100119.json
# Processed: 2021\202100120 -> JsonFile\2021\202100120.json
# Processed: 2021\202100121 -> JsonFile\2021\202100121.json
# Processed: 2021\202100122 -> JsonFile\2021\202100122.json
# Processed: 2021\202100123 -> JsonFile\2021\202100123.json
# Processed: 2021\202100124 -> JsonFile\2021\202100124.json
# Processed: 2021\202100125 -> JsonFile\2021\202100125.json
# Processed: 2021\202100126 -> JsonFile\2021\202100126.json
# Processed: 2021\202100127 -> JsonFile\2021\202100127.json
# Processed: 2021\202100128 -> JsonFile\2021\202100128.json
# Processed: 2021\202100129 -> JsonFile\2021\202100129.json
# Processed: 2021\202100130 -> JsonFile\2021\202100130.json
# Processed: 2021\202100131 -> JsonFile\2021\202100131.json
# Processed: 2021\202100132 -> JsonFile\2021\202100132.json
# Processed: 2021\202100133 -> JsonFile\2021\202100133.json
# Processed: 2021\202100134 -> JsonFile\2021\202100134.json
# Processed: 2021\202100135 -> JsonFile\2021\202100135.json
# Processed: 2021\202100136 -> JsonFile\2021\202100136.json
# Processed: 2021\202100137 -> JsonFile\2021\202100137.json
# Processed: 2021\202100138 -> JsonFile\2021\202100138.json
# Processed: 2021\202100139 -> JsonFile\2021\202100139.json
# Processed: 2021\202100140 -> JsonFile\2021\202100140.json
# Processed: 2021\202100141 -> JsonFile\2021\202100141.json
# Processed: 2021\202100142 -> JsonFile\2021\202100142.json
# Processed: 2021\202100143 -> JsonFile\2021\202100143.json
# Processed: 2021\202100144 -> JsonFile\2021\202100144.json
# Processed: 2021\202100145 -> JsonFile\2021\202100145.json
# Processed: 2021\202100146 -> JsonFile\2021\202100146.json
# Processed: 2021\202100147 -> JsonFile\2021\202100147.json
# Processed: 2021\202100148 -> JsonFile\2021\202100148.json
# Processed: 2021\202100149 -> JsonFile\2021\202100149.json
# Processed: 2021\202100150 -> JsonFile\2021\202100150.json
# Processed: 2021\202100151 -> JsonFile\2021\202100151.json
# Processed: 2021\202100152 -> JsonFile\2021\202100152.json
# Processed: 2021\202100153 -> JsonFile\2021\202100153.json
# Processed: 2021\202100154 -> JsonFile\2021\202100154.json
# Processed: 2021\202100155 -> JsonFile\2021\202100155.json
# Processed: 2021\202100156 -> JsonFile\2021\202100156.json
# Processed: 2021\202100157 -> JsonFile\2021\202100157.json
# Processed: 2021\202100158 -> JsonFile\2021\202100158.json
# Processed: 2021\202100159 -> JsonFile\2021\202100159.json
# Processed: 2021\202100160 -> JsonFile\2021\202100160.json
# Processed: 2021\202100161 -> JsonFile\2021\202100161.json
# Processed: 2021\202100162 -> JsonFile\2021\202100162.json
# Processed: 2021\202100163 -> JsonFile\2021\202100163.json
# Processed: 2021\202100164 -> JsonFile\2021\202100164.json
# Processed: 2021\202100165 -> JsonFile\2021\202100165.json
# Processed: 2021\202100166 -> JsonFile\2021\202100166.json
# Processed: 2021\202100167 -> JsonFile\2021\202100167.json
# Processed: 2021\202100168 -> JsonFile\2021\202100168.json
# Processed: 2021\202100169 -> JsonFile\2021\202100169.json
# Processed: 2021\202100170 -> JsonFile\2021\202100170.json
# Processed: 2021\202100171 -> JsonFile\2021\202100171.json
# Processed: 2021\202100172 -> JsonFile\2021\202100172.json
# Processed: 2021\202100173 -> JsonFile\2021\202100173.json
# Processed: 2021\202100174 -> JsonFile\2021\202100174.json
# Processed: 2021\202100175 -> JsonFile\2021\202100175.json
# Processed: 2021\202100176 -> JsonFile\2021\202100176.json
# Processed: 2021\202100177 -> JsonFile\2021\202100177.json
# Processed: 2021\202100178 -> JsonFile\2021\202100178.json
# Processed: 2021\202100179 -> JsonFile\2021\202100179.json
# Processed: 2021\202100180 -> JsonFile\2021\202100180.json
# Processed: 2021\202100181 -> JsonFile\2021\202100181.json
# Processed: 2021\202100182 -> JsonFile\2021\202100182.json
# Processed: 2021\202100183 -> JsonFile\2021\202100183.json
# Processed: 2021\202100184 -> JsonFile\2021\202100184.json
# Processed: 2021\202100185 -> JsonFile\2021\202100185.json
# Processed: 2021\202100186 -> JsonFile\2021\202100186.json
# Processed: 2021\202100187 -> JsonFile\2021\202100187.json
# Processed: 2021\202100188 -> JsonFile\2021\202100188.json
# Processed: 2021\202100189 -> JsonFile\2021\202100189.json
# Processed: 2021\202100190 -> JsonFile\2021\202100190.json
# Processed: 2021\202100191 -> JsonFile\2021\202100191.json
# Processed: 2021\202100192 -> JsonFile\2021\202100192.json
# Processed: 2021\202100193 -> JsonFile\2021\202100193.json
# Processed: 2021\202100194 -> JsonFile\2021\202100194.json
# Processed: 2021\202100195 -> JsonFile\2021\202100195.json
# Processed: 2021\202100196 -> JsonFile\2021\202100196.json
# Processed: 2021\202100197 -> JsonFile\2021\202100197.json
# Processed: 2021\202100198 -> JsonFile\2021\202100198.json
# Processed: 2021\202100199 -> JsonFile\2021\202100199.json
# Processed: 2021\202100200 -> JsonFile\2021\202100200.json
# Processed: 2021\202100201 -> JsonFile\2021\202100201.json
# Processed: 2021\202100202 -> JsonFile\2021\202100202.json
# Processed: 2021\202100203 -> JsonFile\2021\202100203.json
# Processed: 2021\202100204 -> JsonFile\2021\202100204.json
# Processed: 2021\202100205 -> JsonFile\2021\202100205.json
# Processed: 2021\202100206 -> JsonFile\2021\202100206.json
# Processed: 2021\202100207 -> JsonFile\2021\202100207.json
# Processed: 2021\202100208 -> JsonFile\2021\202100208.json
# Processed: 2021\202100209 -> JsonFile\2021\202100209.json
# Processed: 2021\202100210 -> JsonFile\2021\202100210.json
# Processed: 2021\202100211 -> JsonFile\2021\202100211.json
# Processed: 2021\202100212 -> JsonFile\2021\202100212.json
# Processed: 2021\202100213 -> JsonFile\2021\202100213.json
# Processed: 2021\202100214 -> JsonFile\2021\202100214.json
# Processed: 2021\202100215 -> JsonFile\2021\202100215.json
# Processed: 2021\202100216 -> JsonFile\2021\202100216.json
# Processed: 2021\202100217 -> JsonFile\2021\202100217.json
# Processed: 2021\202100218 -> JsonFile\2021\202100218.json
# Processed: 2021\202100219 -> JsonFile\2021\202100219.json
# Processed: 2021\202100220 -> JsonFile\2021\202100220.json
# Processed: 2021\202100221 -> JsonFile\2021\202100221.json
# Processed: 2021\202100222 -> JsonFile\2021\202100222.json
# Processed: 2021\202100223 -> JsonFile\2021\202100223.json
# Processed: 2021\202100224 -> JsonFile\2021\202100224.json
# Processed: 2021\202100225 -> JsonFile\2021\202100225.json
# Processed: 2021\202100226 -> JsonFile\2021\202100226.json
# Processed: 2021\202100227 -> JsonFile\2021\202100227.json
# Processed: 2021\202100228 -> JsonFile\2021\202100228.json
# Processed: 2021\202100229 -> JsonFile\2021\202100229.json
# Processed: 2021\202100230 -> JsonFile\2021\202100230.json
# Processed: 2021\202100231 -> JsonFile\2021\202100231.json
# Processed: 2021\202100232 -> JsonFile\2021\202100232.json
# Processed: 2021\202100233 -> JsonFile\2021\202100233.json
# Processed: 2021\202100234 -> JsonFile\2021\202100234.json
# Processed: 2021\202100235 -> JsonFile\2021\202100235.json
# Processed: 2021\202100236 -> JsonFile\2021\202100236.json
# Processed: 2021\202100237 -> JsonFile\2021\202100237.json
# Processed: 2021\202100238 -> JsonFile\2021\202100238.json
# Processed: 2021\202100239 -> JsonFile\2021\202100239.json
# Processed: 2021\202100240 -> JsonFile\2021\202100240.json
# Processed: 2021\202100241 -> JsonFile\2021\202100241.json
# Processed: 2021\202100242 -> JsonFile\2021\202100242.json
# Processed: 2021\202100243 -> JsonFile\2021\202100243.json
# Processed: 2021\202100244 -> JsonFile\2021\202100244.json
# Processed: 2021\202100245 -> JsonFile\2021\202100245.json
# Processed: 2021\202100246 -> JsonFile\2021\202100246.json
# Processed: 2021\202100247 -> JsonFile\2021\202100247.json
# Processed: 2021\202100248 -> JsonFile\2021\202100248.json
# Processed: 2021\202100249 -> JsonFile\2021\202100249.json
# Processed: 2021\202100250 -> JsonFile\2021\202100250.json
# Processed: 2021\202100251 -> JsonFile\2021\202100251.json
# Processed: 2021\202100252 -> JsonFile\2021\202100252.json
# Processed: 2021\202100253 -> JsonFile\2021\202100253.json
# Processed: 2021\202100254 -> JsonFile\2021\202100254.json
# Processed: 2021\202100255 -> JsonFile\2021\202100255.json
# Processed: 2021\202100256 -> JsonFile\2021\202100256.json
# Processed: 2021\202100257 -> JsonFile\2021\202100257.json
# Processed: 2021\202100258 -> JsonFile\2021\202100258.json
# Processed: 2021\202100259 -> JsonFile\2021\202100259.json
# Processed: 2021\202100260 -> JsonFile\2021\202100260.json
# Processed: 2021\202100261 -> JsonFile\2021\202100261.json
# Processed: 2021\202100262 -> JsonFile\2021\202100262.json
# Processed: 2021\202100263 -> JsonFile\2021\202100263.json
# Processed: 2021\202100264 -> JsonFile\2021\202100264.json
# Processed: 2021\202100265 -> JsonFile\2021\202100265.json
# Processed: 2021\202100266 -> JsonFile\2021\202100266.json
# Processed: 2021\202100267 -> JsonFile\2021\202100267.json
# Processed: 2021\202100268 -> JsonFile\2021\202100268.json
# Processed: 2021\202100269 -> JsonFile\2021\202100269.json
# Processed: 2021\202100270 -> JsonFile\2021\202100270.json
# Processed: 2021\202100271 -> JsonFile\2021\202100271.json
# Processed: 2021\202100272 -> JsonFile\2021\202100272.json
# Processed: 2021\202100273 -> JsonFile\2021\202100273.json
# Processed: 2021\202100274 -> JsonFile\2021\202100274.json
# Processed: 2021\202100275 -> JsonFile\2021\202100275.json
# Processed: 2021\202100276 -> JsonFile\2021\202100276.json
# Processed: 2021\202100277 -> JsonFile\2021\202100277.json
# Processed: 2021\202100278 -> JsonFile\2021\202100278.json
# Processed: 2021\202100279 -> JsonFile\2021\202100279.json
# Processed: 2021\202100280 -> JsonFile\2021\202100280.json
# Processed: 2021\202100281 -> JsonFile\2021\202100281.json
# Processed: 2021\202100282 -> JsonFile\2021\202100282.json
# Processed: 2021\202100283 -> JsonFile\2021\202100283.json
# Processed: 2021\202100284 -> JsonFile\2021\202100284.json
# Processed: 2021\202100285 -> JsonFile\2021\202100285.json
# Processed: 2021\202100286 -> JsonFile\2021\202100286.json
# Processed: 2021\202100287 -> JsonFile\2021\202100287.json
# Processed: 2021\202100288 -> JsonFile\2021\202100288.json
# Processed: 2021\202100289 -> JsonFile\2021\202100289.json
# Processed: 2021\202100290 -> JsonFile\2021\202100290.json
# Processed: 2021\202100291 -> JsonFile\2021\202100291.json
# Processed: 2021\202100292 -> JsonFile\2021\202100292.json
# Processed: 2021\202100293 -> JsonFile\2021\202100293.json
# Processed: 2021\202100294 -> JsonFile\2021\202100294.json
# Processed: 2021\202100295 -> JsonFile\2021\202100295.json
# Processed: 2021\202100296 -> JsonFile\2021\202100296.json
# Processed: 2021\202100297 -> JsonFile\2021\202100297.json
# Processed: 2021\202100298 -> JsonFile\2021\202100298.json
# Processed: 2021\202100299 -> JsonFile\2021\202100299.json
# Processed: 2021\202100300 -> JsonFile\2021\202100300.json
# Processed: 2021\202100301 -> JsonFile\2021\202100301.json
# Processed: 2021\202100302 -> JsonFile\2021\202100302.json
# Processed: 2021\202100303 -> JsonFile\2021\202100303.json
# Processed: 2021\202100304 -> JsonFile\2021\202100304.json
# Processed: 2021\202100305 -> JsonFile\2021\202100305.json
# Processed: 2021\202100306 -> JsonFile\2021\202100306.json
# Processed: 2021\202100307 -> JsonFile\2021\202100307.json
# Processed: 2021\202100308 -> JsonFile\2021\202100308.json
# Processed: 2021\202100309 -> JsonFile\2021\202100309.json
# Processed: 2021\202100310 -> JsonFile\2021\202100310.json
# Processed: 2021\202100311 -> JsonFile\2021\202100311.json
# Processed: 2021\202100312 -> JsonFile\2021\202100312.json
# Processed: 2021\202100313 -> JsonFile\2021\202100313.json
# Processed: 2021\202100314 -> JsonFile\2021\202100314.json
# Processed: 2021\202100315 -> JsonFile\2021\202100315.json
# Processed: 2021\202100316 -> JsonFile\2021\202100316.json
# Processed: 2021\202100317 -> JsonFile\2021\202100317.json
# Processed: 2021\202100318 -> JsonFile\2021\202100318.json
# Processed: 2021\202100319 -> JsonFile\2021\202100319.json
# Processed: 2021\202100320 -> JsonFile\2021\202100320.json
# Processed: 2021\202100321 -> JsonFile\2021\202100321.json
# Processed: 2021\202100322 -> JsonFile\2021\202100322.json
# Processed: 2021\202100323 -> JsonFile\2021\202100323.json
# Processed: 2021\202100324 -> JsonFile\2021\202100324.json
# Processed: 2021\202100325 -> JsonFile\2021\202100325.json
# Processed: 2021\202100326 -> JsonFile\2021\202100326.json
# Processed: 2021\202100327 -> JsonFile\2021\202100327.json
# Processed: 2021\202100328 -> JsonFile\2021\202100328.json
# Processed: 2021\202100329 -> JsonFile\2021\202100329.json
# Processed: 2021\202100330 -> JsonFile\2021\202100330.json
# Processed: 2021\202100331 -> JsonFile\2021\202100331.json
# Processed: 2021\202100332 -> JsonFile\2021\202100332.json
# Processed: 2021\202100333 -> JsonFile\2021\202100333.json
# Processed: 2021\202100334 -> JsonFile\2021\202100334.json
# Processed: 2021\202100335 -> JsonFile\2021\202100335.json
# Processed: 2021\202100336 -> JsonFile\2021\202100336.json
# Processed: 2021\202100337 -> JsonFile\2021\202100337.json
# Processed: 2021\202100338 -> JsonFile\2021\202100338.json
# Processed: 2021\202100339 -> JsonFile\2021\202100339.json
# Processed: 2021\202100340 -> JsonFile\2021\202100340.json
# Processed: 2021\202100341 -> JsonFile\2021\202100341.json
# Processed: 2021\202100342 -> JsonFile\2021\202100342.json
# Processed: 2021\202100343 -> JsonFile\2021\202100343.json
# Processed: 2021\202100344 -> JsonFile\2021\202100344.json
# Processed: 2021\202100345 -> JsonFile\2021\202100345.json
# Processed: 2021\202100346 -> JsonFile\2021\202100346.json
# Processed: 2021\202100347 -> JsonFile\2021\202100347.json
# Processed: 2021\202100348 -> JsonFile\2021\202100348.json
# Processed: 2021\202100349 -> JsonFile\2021\202100349.json
# Processed: 2021\202100350 -> JsonFile\2021\202100350.json
# Processed: 2021\202100351 -> JsonFile\2021\202100351.json
# Processed: 2021\202100352 -> JsonFile\2021\202100352.json
# Processed: 2021\202100353 -> JsonFile\2021\202100353.json
# Processed: 2021\202100354 -> JsonFile\2021\202100354.json
# Processed: 2021\202100355 -> JsonFile\2021\202100355.json
# Processed: 2021\202100356 -> JsonFile\2021\202100356.json
# Processed: 2021\202100357 -> JsonFile\2021\202100357.json
# Processed: 2021\202100358 -> JsonFile\2021\202100358.json
# Processed: 2021\202100359 -> JsonFile\2021\202100359.json
# Processed: 2021\202100360 -> JsonFile\2021\202100360.json
# Processed: 2021\202100361 -> JsonFile\2021\202100361.json
# Processed: 2021\202100362 -> JsonFile\2021\202100362.json
# Processed: 2021\202100363 -> JsonFile\2021\202100363.json
# Processed: 2021\202100364 -> JsonFile\2021\202100364.json
# Processed: 2021\202100365 -> JsonFile\2021\202100365.json
# Processed: 2021\202100366 -> JsonFile\2021\202100366.json
# Processed: 2021\202100367 -> JsonFile\2021\202100367.json
# Processed: 2021\202100368 -> JsonFile\2021\202100368.json
# Processed: 2021\202100369 -> JsonFile\2021\202100369.json
# Processed: 2021\202100370 -> JsonFile\2021\202100370.json
# Processed: 2021\202100371 -> JsonFile\2021\202100371.json
# Processed: 2021\202100372 -> JsonFile\2021\202100372.json
# Processed: 2021\202100373 -> JsonFile\2021\202100373.json
# Processed: 2021\202100374 -> JsonFile\2021\202100374.json
# Processed: 2021\202100375 -> JsonFile\2021\202100375.json
# Processed: 2021\202100376 -> JsonFile\2021\202100376.json
# Processed: 2021\202100377 -> JsonFile\2021\202100377.json
# Processed: 2021\202100378 -> JsonFile\2021\202100378.json
# Processed: 2021\202100379 -> JsonFile\2021\202100379.json
# Processed: 2021\202100380 -> JsonFile\2021\202100380.json
# Processed: 2021\202100381 -> JsonFile\2021\202100381.json
# Processed: 2021\202100382 -> JsonFile\2021\202100382.json
# Processed: 2021\202100383 -> JsonFile\2021\202100383.json
# Processed: 2021\202100384 -> JsonFile\2021\202100384.json
# Processed: 2021\202100385 -> JsonFile\2021\202100385.json
# Processed: 2021\202100386 -> JsonFile\2021\202100386.json
# Processed: 2021\202100387 -> JsonFile\2021\202100387.json
# Processed: 2021\202100388 -> JsonFile\2021\202100388.json
# Processed: 2021\202100389 -> JsonFile\2021\202100389.json
# Processed: 2021\202100390 -> JsonFile\2021\202100390.json
# Processed: 2021\202100391 -> JsonFile\2021\202100391.json
# Processed: 2021\202100392 -> JsonFile\2021\202100392.json
# Processed: 2021\202100393 -> JsonFile\2021\202100393.json
# Processed: 2021\202100394 -> JsonFile\2021\202100394.json
# Processed: 2021\202100395 -> JsonFile\2021\202100395.json
# Processed: 2021\202100396 -> JsonFile\2021\202100396.json
# Processed: 2021\202100397 -> JsonFile\2021\202100397.json
# Processed: 2021\202100398 -> JsonFile\2021\202100398.json
# Processed: 2021\202100399 -> JsonFile\2021\202100399.json
# Processed: 2021\202100400 -> JsonFile\2021\202100400.json
# Processed: 2021\202100401 -> JsonFile\2021\202100401.json
# Processed: 2021\202100402 -> JsonFile\2021\202100402.json
# Processed: 2021\202100403 -> JsonFile\2021\202100403.json
# Processed: 2021\202100404 -> JsonFile\2021\202100404.json
# Processed: 2021\202100405 -> JsonFile\2021\202100405.json
# Processed: 2021\202100406 -> JsonFile\2021\202100406.json
# Processed: 2021\202100407 -> JsonFile\2021\202100407.json
# Processed: 2021\202100408 -> JsonFile\2021\202100408.json
# Processed: 2021\202100409 -> JsonFile\2021\202100409.json
# Processed: 2021\202100410 -> JsonFile\2021\202100410.json
# Processed: 2021\202100411 -> JsonFile\2021\202100411.json
# Processed: 2021\202100412 -> JsonFile\2021\202100412.json
# Processed: 2021\202100413 -> JsonFile\2021\202100413.json
# Processed: 2021\202100414 -> JsonFile\2021\202100414.json
# Processed: 2021\202100415 -> JsonFile\2021\202100415.json
# Processed: 2021\202100416 -> JsonFile\2021\202100416.json
# Processed: 2021\202100417 -> JsonFile\2021\202100417.json
# Processed: 2021\202100418 -> JsonFile\2021\202100418.json
# Processed: 2021\202100419 -> JsonFile\2021\202100419.json
# Processed: 2021\202100420 -> JsonFile\2021\202100420.json
# Processed: 2021\202100421 -> JsonFile\2021\202100421.json
# Processed: 2021\202100422 -> JsonFile\2021\202100422.json
# Processed: 2021\202100423 -> JsonFile\2021\202100423.json
# Processed: 2021\202100424 -> JsonFile\2021\202100424.json
# Processed: 2021\202100425 -> JsonFile\2021\202100425.json
# Processed: 2021\202100426 -> JsonFile\2021\202100426.json
# Processed: 2021\202100427 -> JsonFile\2021\202100427.json
# Processed: 2021\202100428 -> JsonFile\2021\202100428.json
# Processed: 2021\202100429 -> JsonFile\2021\202100429.json
# Processed: 2021\202100430 -> JsonFile\2021\202100430.json
# Processed: 2021\202100431 -> JsonFile\2021\202100431.json
# Processed: 2021\202100432 -> JsonFile\2021\202100432.json
# Processed: 2021\202100433 -> JsonFile\2021\202100433.json
# Processed: 2021\202100434 -> JsonFile\2021\202100434.json
# Processed: 2021\202100435 -> JsonFile\2021\202100435.json
# Processed: 2021\202100436 -> JsonFile\2021\202100436.json
# Processed: 2021\202100437 -> JsonFile\2021\202100437.json
# Processed: 2021\202100438 -> JsonFile\2021\202100438.json
# Processed: 2021\202100439 -> JsonFile\2021\202100439.json
# Processed: 2021\202100440 -> JsonFile\2021\202100440.json
# Processed: 2021\202100441 -> JsonFile\2021\202100441.json
# Processed: 2021\202100442 -> JsonFile\2021\202100442.json
# Processed: 2021\202100443 -> JsonFile\2021\202100443.json
# Processed: 2021\202100444 -> JsonFile\2021\202100444.json
# Processed: 2021\202100445 -> JsonFile\2021\202100445.json
# Processed: 2021\202100446 -> JsonFile\2021\202100446.json
# Processed: 2021\202100447 -> JsonFile\2021\202100447.json
# Processed: 2021\202100448 -> JsonFile\2021\202100448.json
# Processed: 2021\202100449 -> JsonFile\2021\202100449.json
# Processed: 2021\202100450 -> JsonFile\2021\202100450.json
# Processed: 2021\202100451 -> JsonFile\2021\202100451.json
# Processed: 2021\202100452 -> JsonFile\2021\202100452.json
# Processed: 2021\202100453 -> JsonFile\2021\202100453.json
# Processed: 2021\202100454 -> JsonFile\2021\202100454.json
# Processed: 2021\202100455 -> JsonFile\2021\202100455.json
# Processed: 2021\202100456 -> JsonFile\2021\202100456.json
# Processed: 2021\202100457 -> JsonFile\2021\202100457.json
# Processed: 2021\202100458 -> JsonFile\2021\202100458.json
# Processed: 2021\202100459 -> JsonFile\2021\202100459.json
# Processed: 2021\202100460 -> JsonFile\2021\202100460.json
# Processed: 2021\202100461 -> JsonFile\2021\202100461.json
# Processed: 2021\202100462 -> JsonFile\2021\202100462.json
# Processed: 2021\202100463 -> JsonFile\2021\202100463.json
# Processed: 2021\202100464 -> JsonFile\2021\202100464.json
# Processed: 2021\202100465 -> JsonFile\2021\202100465.json
# Processed: 2021\202100466 -> JsonFile\2021\202100466.json
# Processed: 2021\202100467 -> JsonFile\2021\202100467.json
# Processed: 2021\202100468 -> JsonFile\2021\202100468.json
# Processed: 2021\202100469 -> JsonFile\2021\202100469.json
# Processed: 2021\202100470 -> JsonFile\2021\202100470.json
# Processed: 2021\202100471 -> JsonFile\2021\202100471.json
# Processed: 2021\202100472 -> JsonFile\2021\202100472.json
# Processed: 2021\202100473 -> JsonFile\2021\202100473.json
# Processed: 2021\202100474 -> JsonFile\2021\202100474.json
# Processed: 2021\202100475 -> JsonFile\2021\202100475.json
# Processed: 2021\202100476 -> JsonFile\2021\202100476.json
# Processed: 2021\202100477 -> JsonFile\2021\202100477.json
# Processed: 2021\202100478 -> JsonFile\2021\202100478.json
# Processed: 2021\202100479 -> JsonFile\2021\202100479.json
# Processed: 2021\202100480 -> JsonFile\2021\202100480.json
# Processed: 2021\202100481 -> JsonFile\2021\202100481.json
# Processed: 2021\202100482 -> JsonFile\2021\202100482.json
# Processed: 2021\202100483 -> JsonFile\2021\202100483.json
# Processed: 2021\202100484 -> JsonFile\2021\202100484.json
# Processed: 2021\202100485 -> JsonFile\2021\202100485.json
# Processed: 2021\202100486 -> JsonFile\2021\202100486.json
# Processed: 2021\202100487 -> JsonFile\2021\202100487.json
# Processed: 2021\202100488 -> JsonFile\2021\202100488.json
# Processed: 2021\202100489 -> JsonFile\2021\202100489.json
# Processed: 2021\202100490 -> JsonFile\2021\202100490.json
# Processed: 2021\202100491 -> JsonFile\2021\202100491.json
# Processed: 2021\202100492 -> JsonFile\2021\202100492.json
# Processed: 2021\202100493 -> JsonFile\2021\202100493.json
# Processed: 2021\202100494 -> JsonFile\2021\202100494.json
# Processed: 2021\202100495 -> JsonFile\2021\202100495.json
# Processed: 2021\202100496 -> JsonFile\2021\202100496.json
# Processed: 2021\202100497 -> JsonFile\2021\202100497.json
# Processed: 2021\202100498 -> JsonFile\2021\202100498.json
# Processed: 2021\202100499 -> JsonFile\2021\202100499.json
# Processed: 2021\202100500 -> JsonFile\2021\202100500.json
# Processed: 2021\202100501 -> JsonFile\2021\202100501.json
# Processed: 2021\202100502 -> JsonFile\2021\202100502.json
# Processed: 2021\202100503 -> JsonFile\2021\202100503.json
# Processed: 2021\202100504 -> JsonFile\2021\202100504.json
# Processed: 2021\202100505 -> JsonFile\2021\202100505.json
# Processed: 2021\202100506 -> JsonFile\2021\202100506.json
# Processed: 2021\202100507 -> JsonFile\2021\202100507.json
# Processed: 2021\202100508 -> JsonFile\2021\202100508.json
# Processed: 2021\202100509 -> JsonFile\2021\202100509.json
# Processed: 2021\202100510 -> JsonFile\2021\202100510.json
# Processed: 2021\202100511 -> JsonFile\2021\202100511.json
# Processed: 2021\202100512 -> JsonFile\2021\202100512.json
# Processed: 2021\202100513 -> JsonFile\2021\202100513.json
# Processed: 2021\202100514 -> JsonFile\2021\202100514.json
# Processed: 2021\202100515 -> JsonFile\2021\202100515.json
# Processed: 2021\202100516 -> JsonFile\2021\202100516.json
# Processed: 2021\202100517 -> JsonFile\2021\202100517.json
# Processed: 2021\202100518 -> JsonFile\2021\202100518.json
# Processed: 2021\202100519 -> JsonFile\2021\202100519.json
# Processed: 2021\202100520 -> JsonFile\2021\202100520.json
# Processed: 2021\202100521 -> JsonFile\2021\202100521.json
# Processed: 2021\202100522 -> JsonFile\2021\202100522.json
# Processed: 2021\202100523 -> JsonFile\2021\202100523.json
# Processed: 2021\202100524 -> JsonFile\2021\202100524.json
# Processed: 2021\202100525 -> JsonFile\2021\202100525.json
# Processed: 2021\202100526 -> JsonFile\2021\202100526.json
# Processed: 2021\202100527 -> JsonFile\2021\202100527.json
# Processed: 2021\202100528 -> JsonFile\2021\202100528.json
# Processed: 2021\202100529 -> JsonFile\2021\202100529.json
# Processed: 2021\202100530 -> JsonFile\2021\202100530.json
# Processed: 2021\202100531 -> JsonFile\2021\202100531.json
# Processed: 2021\202100532 -> JsonFile\2021\202100532.json
# Processed: 2021\202100533 -> JsonFile\2021\202100533.json
# Processed: 2021\202100534 -> JsonFile\2021\202100534.json
# Processed: 2021\202100535 -> JsonFile\2021\202100535.json
# Processed: 2021\202100536 -> JsonFile\2021\202100536.json
# Processed: 2021\202100537 -> JsonFile\2021\202100537.json
# Processed: 2021\202100538 -> JsonFile\2021\202100538.json
# Processed: 2021\202100539 -> JsonFile\2021\202100539.json
# Processed: 2021\202100540 -> JsonFile\2021\202100540.json
# Processed: 2021\202100541 -> JsonFile\2021\202100541.json
# Processed: 2021\202100542 -> JsonFile\2021\202100542.json
# Processed: 2021\202100543 -> JsonFile\2021\202100543.json
# Processed: 2021\202100544 -> JsonFile\2021\202100544.json
# Processed: 2021\202100545 -> JsonFile\2021\202100545.json
# Processed: 2021\202100546 -> JsonFile\2021\202100546.json
# Processed: 2021\202100547 -> JsonFile\2021\202100547.json
# Processed: 2021\202100548 -> JsonFile\2021\202100548.json
# Processed: 2021\202100549 -> JsonFile\2021\202100549.json
# Processed: 2021\202100550 -> JsonFile\2021\202100550.json
# Processed: 2021\202100551 -> JsonFile\2021\202100551.json
# Processed: 2021\202100552 -> JsonFile\2021\202100552.json
# Processed: 2021\202100553 -> JsonFile\2021\202100553.json
# Processed: 2021\202100554 -> JsonFile\2021\202100554.json
# Processed: 2021\202100555 -> JsonFile\2021\202100555.json
# Processed: 2021\202100556 -> JsonFile\2021\202100556.json
# Processed: 2021\202100557 -> JsonFile\2021\202100557.json
# Processed: 2021\202100558 -> JsonFile\2021\202100558.json
# Processed: 2021\202100559 -> JsonFile\2021\202100559.json
# Processed: 2021\202100560 -> JsonFile\2021\202100560.json
# Processed: 2021\202100561 -> JsonFile\2021\202100561.json
# Processed: 2021\202100562 -> JsonFile\2021\202100562.json
# Processed: 2021\202100563 -> JsonFile\2021\202100563.json
# Processed: 2021\202100564 -> JsonFile\2021\202100564.json
# Processed: 2021\202100565 -> JsonFile\2021\202100565.json
# Processed: 2021\202100566 -> JsonFile\2021\202100566.json
# Processed: 2021\202100567 -> JsonFile\2021\202100567.json
# Processed: 2021\202100568 -> JsonFile\2021\202100568.json
# Processed: 2021\202100569 -> JsonFile\2021\202100569.json
# Processed: 2021\202100570 -> JsonFile\2021\202100570.json
# Processed: 2021\202100571 -> JsonFile\2021\202100571.json
# Processed: 2021\202100572 -> JsonFile\2021\202100572.json
# Processed: 2021\202100573 -> JsonFile\2021\202100573.json
# Processed: 2021\202100574 -> JsonFile\2021\202100574.json
# Processed: 2021\202100575 -> JsonFile\2021\202100575.json
# Processed: 2021\202100576 -> JsonFile\2021\202100576.json
# Processed: 2021\202100577 -> JsonFile\2021\202100577.json
# Processed: 2021\202100578 -> JsonFile\2021\202100578.json
# Processed: 2021\202100579 -> JsonFile\2021\202100579.json
# Processed: 2021\202100580 -> JsonFile\2021\202100580.json
# Processed: 2021\202100581 -> JsonFile\2021\202100581.json
# Processed: 2021\202100582 -> JsonFile\2021\202100582.json
# Processed: 2021\202100583 -> JsonFile\2021\202100583.json
# Processed: 2021\202100584 -> JsonFile\2021\202100584.json
# Processed: 2021\202100585 -> JsonFile\2021\202100585.json
# Processed: 2021\202100586 -> JsonFile\2021\202100586.json
# Processed: 2021\202100587 -> JsonFile\2021\202100587.json
# Processed: 2021\202100588 -> JsonFile\2021\202100588.json
# Processed: 2021\202100589 -> JsonFile\2021\202100589.json
# Processed: 2021\202100590 -> JsonFile\2021\202100590.json
# Processed: 2021\202100591 -> JsonFile\2021\202100591.json
# Processed: 2021\202100592 -> JsonFile\2021\202100592.json
# Processed: 2021\202100593 -> JsonFile\2021\202100593.json
# Processed: 2021\202100594 -> JsonFile\2021\202100594.json
# Processed: 2021\202100595 -> JsonFile\2021\202100595.json
# Processed: 2021\202100596 -> JsonFile\2021\202100596.json
# Processed: 2021\202100597 -> JsonFile\2021\202100597.json
# Processed: 2021\202100598 -> JsonFile\2021\202100598.json
# Processed: 2021\202100599 -> JsonFile\2021\202100599.json
# Processed: 2021\202100600 -> JsonFile\2021\202100600.json
# Processed: 2021\202100601 -> JsonFile\2021\202100601.json
# Processed: 2021\202100602 -> JsonFile\2021\202100602.json
# Processed: 2021\202100603 -> JsonFile\2021\202100603.json
# Processed: 2021\202100604 -> JsonFile\2021\202100604.json
# Processed: 2021\202100605 -> JsonFile\2021\202100605.json
# Processed: 2021\202100606 -> JsonFile\2021\202100606.json
# Processed: 2021\202100607 -> JsonFile\2021\202100607.json
# Processed: 2021\202100608 -> JsonFile\2021\202100608.json
# Processed: 2021\202100609 -> JsonFile\2021\202100609.json
# Processed: 2021\202100610 -> JsonFile\2021\202100610.json
# Processed: 2021\202100611 -> JsonFile\2021\202100611.json
# Processed: 2021\202100612 -> JsonFile\2021\202100612.json
# Processed: 2021\202100613 -> JsonFile\2021\202100613.json
# Processed: 2021\202100614 -> JsonFile\2021\202100614.json
# Processed: 2021\202100615 -> JsonFile\2021\202100615.json
# Processed: 2021\202100616 -> JsonFile\2021\202100616.json
# Processed: 2021\202100617 -> JsonFile\2021\202100617.json
# Processed: 2021\202100618 -> JsonFile\2021\202100618.json
# Processed: 2021\202100619 -> JsonFile\2021\202100619.json
# Processed: 2021\202100620 -> JsonFile\2021\202100620.json
# Processed: 2021\202100621 -> JsonFile\2021\202100621.json
# Processed: 2021\202100622 -> JsonFile\2021\202100622.json
# Processed: 2021\202100623 -> JsonFile\2021\202100623.json
# Processed: 2021\202100624 -> JsonFile\2021\202100624.json
# Processed: 2021\202100625 -> JsonFile\2021\202100625.json
# Processed: 2021\202100626 -> JsonFile\2021\202100626.json
# Processed: 2021\202100627 -> JsonFile\2021\202100627.json
# Processed: 2021\202100628 -> JsonFile\2021\202100628.json
# Processed: 2021\202100629 -> JsonFile\2021\202100629.json
# Processed: 2021\202100630 -> JsonFile\2021\202100630.json
# Processed: 2021\202100631 -> JsonFile\2021\202100631.json
# Processed: 2021\202100632 -> JsonFile\2021\202100632.json
# Processed: 2021\202100633 -> JsonFile\2021\202100633.json
# Processed: 2021\202100634 -> JsonFile\2021\202100634.json
# Processed: 2021\202100635 -> JsonFile\2021\202100635.json
# Processed: 2021\202100636 -> JsonFile\2021\202100636.json
# Processed: 2021\202100637 -> JsonFile\2021\202100637.json
# Processed: 2021\202100638 -> JsonFile\2021\202100638.json
# Processed: 2021\202100639 -> JsonFile\2021\202100639.json
# Processed: 2021\202100640 -> JsonFile\2021\202100640.json
# Processed: 2021\202100641 -> JsonFile\2021\202100641.json
# Processed: 2021\202100642 -> JsonFile\2021\202100642.json
# Processed: 2021\202100643 -> JsonFile\2021\202100643.json
# Processed: 2021\202100644 -> JsonFile\2021\202100644.json
# Processed: 2021\202100645 -> JsonFile\2021\202100645.json
# Processed: 2021\202100646 -> JsonFile\2021\202100646.json
# Processed: 2021\202100647 -> JsonFile\2021\202100647.json
# Processed: 2021\202100648 -> JsonFile\2021\202100648.json
# Processed: 2021\202100649 -> JsonFile\2021\202100649.json
# Processed: 2021\202100650 -> JsonFile\2021\202100650.json
# Processed: 2021\202100651 -> JsonFile\2021\202100651.json
# Processed: 2021\202100652 -> JsonFile\2021\202100652.json
# Processed: 2021\202100653 -> JsonFile\2021\202100653.json
# Processed: 2021\202100654 -> JsonFile\2021\202100654.json
# Processed: 2021\202100655 -> JsonFile\2021\202100655.json
# Processed: 2021\202100656 -> JsonFile\2021\202100656.json
# Processed: 2021\202100657 -> JsonFile\2021\202100657.json
# Processed: 2021\202100658 -> JsonFile\2021\202100658.json
# Processed: 2021\202100659 -> JsonFile\2021\202100659.json
# Processed: 2021\202100660 -> JsonFile\2021\202100660.json
# Processed: 2021\202100661 -> JsonFile\2021\202100661.json
# Processed: 2021\202100662 -> JsonFile\2021\202100662.json
# Processed: 2021\202100663 -> JsonFile\2021\202100663.json
# Processed: 2021\202100664 -> JsonFile\2021\202100664.json
# Processed: 2021\202100665 -> JsonFile\2021\202100665.json
# Processed: 2021\202100666 -> JsonFile\2021\202100666.json
# Processed: 2021\202100667 -> JsonFile\2021\202100667.json
# Processed: 2021\202100668 -> JsonFile\2021\202100668.json
# Processed: 2021\202100669 -> JsonFile\2021\202100669.json
# Processed: 2021\202100670 -> JsonFile\2021\202100670.json
# Processed: 2021\202100671 -> JsonFile\2021\202100671.json
# Processed: 2021\202100672 -> JsonFile\2021\202100672.json
# Processed: 2021\202100673 -> JsonFile\2021\202100673.json
# Processed: 2021\202100674 -> JsonFile\2021\202100674.json
# Processed: 2021\202100675 -> JsonFile\2021\202100675.json
# Processed: 2021\202100676 -> JsonFile\2021\202100676.json
# Processed: 2021\202100677 -> JsonFile\2021\202100677.json
# Processed: 2021\202100678 -> JsonFile\2021\202100678.json
# Processed: 2021\202100679 -> JsonFile\2021\202100679.json
# Processed: 2021\202100680 -> JsonFile\2021\202100680.json
# Processed: 2021\202100681 -> JsonFile\2021\202100681.json
# Processed: 2021\202100682 -> JsonFile\2021\202100682.json
# Processed: 2021\202100683 -> JsonFile\2021\202100683.json
# Processed: 2021\202100684 -> JsonFile\2021\202100684.json
# Processed: 2021\202100685 -> JsonFile\2021\202100685.json
# Processed: 2021\202100686 -> JsonFile\2021\202100686.json
# Processed: 2021\202100687 -> JsonFile\2021\202100687.json
# Processed: 2021\202100688 -> JsonFile\2021\202100688.json
# Processed: 2021\202100689 -> JsonFile\2021\202100689.json
# Processed: 2021\202100690 -> JsonFile\2021\202100690.json
# Processed: 2021\202100691 -> JsonFile\2021\202100691.json
# Processed: 2021\202100692 -> JsonFile\2021\202100692.json
# Processed: 2021\202100693 -> JsonFile\2021\202100693.json
# Processed: 2021\202100694 -> JsonFile\2021\202100694.json
# Processed: 2021\202100695 -> JsonFile\2021\202100695.json
# Processed: 2021\202100696 -> JsonFile\2021\202100696.json
# Processed: 2021\202100697 -> JsonFile\2021\202100697.json
# Processed: 2021\202100698 -> JsonFile\2021\202100698.json
# Processed: 2021\202100699 -> JsonFile\2021\202100699.json
# Processed: 2021\202100700 -> JsonFile\2021\202100700.json
# Processed: 2021\202100701 -> JsonFile\2021\202100701.json
# Processed: 2021\202100702 -> JsonFile\2021\202100702.json
# Processed: 2021\202100703 -> JsonFile\2021\202100703.json
# Processed: 2021\202100704 -> JsonFile\2021\202100704.json
# Processed: 2021\202100705 -> JsonFile\2021\202100705.json
# Processed: 2021\202100706 -> JsonFile\2021\202100706.json
# Processed: 2021\202100707 -> JsonFile\2021\202100707.json
# Processed: 2021\202100708 -> JsonFile\2021\202100708.json
# Processed: 2021\202100709 -> JsonFile\2021\202100709.json
# Processed: 2021\202100710 -> JsonFile\2021\202100710.json
# Processed: 2021\202100711 -> JsonFile\2021\202100711.json
# Processed: 2021\202100712 -> JsonFile\2021\202100712.json
# Processed: 2021\202100713 -> JsonFile\2021\202100713.json
# Processed: 2021\202100714 -> JsonFile\2021\202100714.json
# Processed: 2021\202100715 -> JsonFile\2021\202100715.json
# Processed: 2021\202100716 -> JsonFile\2021\202100716.json
# Processed: 2021\202100717 -> JsonFile\2021\202100717.json
# Processed: 2021\202100718 -> JsonFile\2021\202100718.json
# Processed: 2021\202100719 -> JsonFile\2021\202100719.json
# Processed: 2021\202100720 -> JsonFile\2021\202100720.json
# Processed: 2021\202100721 -> JsonFile\2021\202100721.json
# Processed: 2021\202100722 -> JsonFile\2021\202100722.json
# Processed: 2021\202100723 -> JsonFile\2021\202100723.json
# Processed: 2021\202100724 -> JsonFile\2021\202100724.json
# Processed: 2021\202100725 -> JsonFile\2021\202100725.json
# Processed: 2021\202100726 -> JsonFile\2021\202100726.json
# Processed: 2021\202100727 -> JsonFile\2021\202100727.json
# Processed: 2021\202100728 -> JsonFile\2021\202100728.json
# Processed: 2021\202100729 -> JsonFile\2021\202100729.json
# Processed: 2021\202100730 -> JsonFile\2021\202100730.json
# Processed: 2021\202100731 -> JsonFile\2021\202100731.json
# Processed: 2021\202100732 -> JsonFile\2021\202100732.json
# Processed: 2021\202100733 -> JsonFile\2021\202100733.json
# Processed: 2021\202100734 -> JsonFile\2021\202100734.json
# Processed: 2021\202100735 -> JsonFile\2021\202100735.json
# Processed: 2021\202100736 -> JsonFile\2021\202100736.json
# Processed: 2021\202100737 -> JsonFile\2021\202100737.json
# Processed: 2021\202100738 -> JsonFile\2021\202100738.json
# Processed: 2021\202100739 -> JsonFile\2021\202100739.json
# Processed: 2021\202100740 -> JsonFile\2021\202100740.json
# Processed: 2021\202100741 -> JsonFile\2021\202100741.json
# Processed: 2021\202100742 -> JsonFile\2021\202100742.json
# Processed: 2021\202100743 -> JsonFile\2021\202100743.json
# Processed: 2021\202100744 -> JsonFile\2021\202100744.json
# Processed: 2021\202100745 -> JsonFile\2021\202100745.json
# Processed: 2021\202100746 -> JsonFile\2021\202100746.json
# Processed: 2021\202100747 -> JsonFile\2021\202100747.json
# Processed: 2021\202100748 -> JsonFile\2021\202100748.json
# Processed: 2021\202100749 -> JsonFile\2021\202100749.json
# Processed: 2021\202100750 -> JsonFile\2021\202100750.json
# Processed: 2021\202100751 -> JsonFile\2021\202100751.json
# Processed: 2021\202100752 -> JsonFile\2021\202100752.json
# Processed: 2021\202100753 -> JsonFile\2021\202100753.json
# Processed: 2021\202100754 -> JsonFile\2021\202100754.json
# Processed: 2021\202100755 -> JsonFile\2021\202100755.json
# Processed: 2021\202100756 -> JsonFile\2021\202100756.json
# Processed: 2021\202100757 -> JsonFile\2021\202100757.json
# Processed: 2021\202100758 -> JsonFile\2021\202100758.json
# Processed: 2021\202100759 -> JsonFile\2021\202100759.json
# Processed: 2021\202100760 -> JsonFile\2021\202100760.json
# Processed: 2021\202100761 -> JsonFile\2021\202100761.json
# Processed: 2021\202100762 -> JsonFile\2021\202100762.json
# Processed: 2021\202100763 -> JsonFile\2021\202100763.json
# Processed: 2021\202100764 -> JsonFile\2021\202100764.json
# Processed: 2021\202100765 -> JsonFile\2021\202100765.json
# Processed: 2021\202100766 -> JsonFile\2021\202100766.json
# Processed: 2021\202100767 -> JsonFile\2021\202100767.json
# Processed: 2021\202100768 -> JsonFile\2021\202100768.json
# Processed: 2021\202100769 -> JsonFile\2021\202100769.json
# Processed: 2021\202100770 -> JsonFile\2021\202100770.json
# Processed: 2021\202100771 -> JsonFile\2021\202100771.json
# Processed: 2021\202100772 -> JsonFile\2021\202100772.json
# Processed: 2021\202100773 -> JsonFile\2021\202100773.json
# Processed: 2021\202100774 -> JsonFile\2021\202100774.json
# Processed: 2021\202100775 -> JsonFile\2021\202100775.json
# Processed: 2021\202100776 -> JsonFile\2021\202100776.json
# Processed: 2021\202100777 -> JsonFile\2021\202100777.json
# Processed: 2021\202100778 -> JsonFile\2021\202100778.json
# Processed: 2021\202100779 -> JsonFile\2021\202100779.json
# Processed: 2021\202100780 -> JsonFile\2021\202100780.json
# Processed: 2021\202100781 -> JsonFile\2021\202100781.json
# Processed: 2021\202100782 -> JsonFile\2021\202100782.json
# Processed: 2021\202100783 -> JsonFile\2021\202100783.json
# Processed: 2021\202100784 -> JsonFile\2021\202100784.json
# Processed: 2021\202100785 -> JsonFile\2021\202100785.json
# Processed: 2021\202100786 -> JsonFile\2021\202100786.json
# Processed: 2021\202100787 -> JsonFile\2021\202100787.json
# Processed: 2021\202100788 -> JsonFile\2021\202100788.json
# Processed: 2021\202100789 -> JsonFile\2021\202100789.json
# Processed: 2021\202100790 -> JsonFile\2021\202100790.json
# Processed: 2021\202100791 -> JsonFile\2021\202100791.json
# Processed: 2021\202100792 -> JsonFile\2021\202100792.json
# Processed: 2021\202100793 -> JsonFile\2021\202100793.json
# Processed: 2021\202100794 -> JsonFile\2021\202100794.json
# Processed: 2021\202100795 -> JsonFile\2021\202100795.json
# Processed: 2021\202100796 -> JsonFile\2021\202100796.json
# Processed: 2021\202100797 -> JsonFile\2021\202100797.json
# Processed: 2021\202100798 -> JsonFile\2021\202100798.json
# Processed: 2021\202100799 -> JsonFile\2021\202100799.json
# Processed: 2021\202100800 -> JsonFile\2021\202100800.json
# Processed: 2021\202100801 -> JsonFile\2021\202100801.json
# Processed: 2021\202100802 -> JsonFile\2021\202100802.json
# Processed: 2021\202100803 -> JsonFile\2021\202100803.json
# Processed: 2021\202100804 -> JsonFile\2021\202100804.json
# Processed: 2021\202100805 -> JsonFile\2021\202100805.json
# Processed: 2021\202100806 -> JsonFile\2021\202100806.json
# Processed: 2021\202100807 -> JsonFile\2021\202100807.json
# Processed: 2021\202100808 -> JsonFile\2021\202100808.json
# Processed: 2021\202100809 -> JsonFile\2021\202100809.json
# Processed: 2021\202100810 -> JsonFile\2021\202100810.json
# Processed: 2021\202100811 -> JsonFile\2021\202100811.json
# Processed: 2021\202100812 -> JsonFile\2021\202100812.json
# Processed: 2021\202100813 -> JsonFile\2021\202100813.json
# Processed: 2021\202100814 -> JsonFile\2021\202100814.json
# Processed: 2021\202100815 -> JsonFile\2021\202100815.json
# Processed: 2021\202100816 -> JsonFile\2021\202100816.json
# Processed: 2021\202100817 -> JsonFile\2021\202100817.json
# Processed: 2021\202100818 -> JsonFile\2021\202100818.json
# Processed: 2021\202100819 -> JsonFile\2021\202100819.json
# Processed: 2021\202100820 -> JsonFile\2021\202100820.json
# Processed: 2021\202100821 -> JsonFile\2021\202100821.json
# Processed: 2021\202100822 -> JsonFile\2021\202100822.json
# Processed: 2021\202100823 -> JsonFile\2021\202100823.json
# Processed: 2021\202100824 -> JsonFile\2021\202100824.json
# Processed: 2021\202100825 -> JsonFile\2021\202100825.json
# Processed: 2021\202100826 -> JsonFile\2021\202100826.json
# ...
# Processed: 2023\202302615 -> JsonFile\2023\202302615.json
# Processed: 2023\202302616 -> JsonFile\2023\202302616.json
# Processed: 2023\202302617 -> JsonFile\2023\202302617.json
# Processed: 2023\202302618 -> JsonFile\2023\202302618.json
# Processed: 2023\202302619 -> JsonFile\2023\202302619.json
# Processed: 2023\202302620 -> JsonFile\2023\202302620.json
# Processed: 2023\202302621 -> JsonFile\2023\202302621.json
# Processed: 2023\202302622 -> JsonFile\2023\202302622.json
# Processed: 2023\202302623 -> JsonFile\2023\202302623.json
# Processed: 2023\202302624 -> JsonFile\2023\202302624.json
# Processed: 2023\202302625 -> JsonFile\2023\202302625.json
# Processed: 2023\202302626 -> JsonFile\2023\202302626.json
# Processed: 2023\202302627 -> JsonFile\2023\202302627.json
# Processed: 2023\202302628 -> JsonFile\2023\202302628.json
# Processed: 2023\202302629 -> JsonFile\2023\202302629.json
# Processed: 2023\202302630 -> JsonFile\2023\202302630.json
# Processed: 2023\202302631 -> JsonFile\2023\202302631.json
# Processed: 2023\202302632 -> JsonFile\2023\202302632.json
# Processed: 2023\202302633 -> JsonFile\2023\202302633.json
# Processed: 2023\202302634 -> JsonFile\2023\202302634.json
# Processed: 2023\202302635 -> JsonFile\2023\202302635.json
# Processed: 2023\202302636 -> JsonFile\2023\202302636.json
# Processed: 2023\202302637 -> JsonFile\2023\202302637.json
# Processed: 2023\202302638 -> JsonFile\2023\202302638.json
# Processed: 2023\202302639 -> JsonFile\2023\202302639.json
# Processed: 2023\202302640 -> JsonFile\2023\202302640.json
# Processed: 2023\202302641 -> JsonFile\2023\202302641.json
# Processed: 2023\202302642 -> JsonFile\2023\202302642.json
# Processed: 2023\202302643 -> JsonFile\2023\202302643.json
# Processed: 2023\202302644 -> JsonFile\2023\202302644.json
# Processed: 2023\202302645 -> JsonFile\2023\202302645.json
# Processed: 2023\202302646 -> JsonFile\2023\202302646.json
# Processed: 2023\202302647 -> JsonFile\2023\202302647.json
# Processed: 2023\202302648 -> JsonFile\2023\202302648.json
# Processed: 2023\202302649 -> JsonFile\2023\202302649.json
# Processed: 2023\202302650 -> JsonFile\2023\202302650.json
# Processed: 2023\202302651 -> JsonFile\2023\202302651.json
# Processed: 2023\202302652 -> JsonFile\2023\202302652.json
# Processed: 2023\202302653 -> JsonFile\2023\202302653.json
# Processed: 2023\202302654 -> JsonFile\2023\202302654.json
# Processed: 2023\202302655 -> JsonFile\2023\202302655.json
# Processed: 2023\202302656 -> JsonFile\2023\202302656.json
# Processed: 2023\202302657 -> JsonFile\2023\202302657.json
# Processed: 2023\202302658 -> JsonFile\2023\202302658.json
# Processed: 2023\202302659 -> JsonFile\2023\202302659.json
# Processed: 2023\202302660 -> JsonFile\2023\202302660.json
# Processed: 2023\202302661 -> JsonFile\2023\202302661.json
# Processed: 2023\202302662 -> JsonFile\2023\202302662.json
# Processed: 2023\202302663 -> JsonFile\2023\202302663.json
# Processed: 2023\202302664 -> JsonFile\2023\202302664.json
# Processed: 2023\202302665 -> JsonFile\2023\202302665.json
# Processed: 2023\202302666 -> JsonFile\2023\202302666.json
# Processed: 2023\202302667 -> JsonFile\2023\202302667.json
# Processed: 2023\202302668 -> JsonFile\2023\202302668.json
# Processed: 2023\202302669 -> JsonFile\2023\202302669.json
# Processed: 2023\202302670 -> JsonFile\2023\202302670.json
# Processed: 2023\202302671 -> JsonFile\2023\202302671.json
# Processed: 2023\202302672 -> JsonFile\2023\202302672.json
# Processed: 2023\202302673 -> JsonFile\2023\202302673.json
# Processed: 2023\202302674 -> JsonFile\2023\202302674.json
# Processed: 2023\202302675 -> JsonFile\2023\202302675.json
# Processed: 2023\202302676 -> JsonFile\2023\202302676.json
# Processed: 2023\202302677 -> JsonFile\2023\202302677.json
# Processed: 2023\202302678 -> JsonFile\2023\202302678.json
# Processed: 2023\202302679 -> JsonFile\2023\202302679.json
# Processed: 2023\202302680 -> JsonFile\2023\202302680.json
# Processed: 2023\202302681 -> JsonFile\2023\202302681.json
# Processed: 2023\202302682 -> JsonFile\2023\202302682.json
# Processed: 2023\202302683 -> JsonFile\2023\202302683.json
# Processed: 2023\202302684 -> JsonFile\2023\202302684.json
# Processed: 2023\202302685 -> JsonFile\2023\202302685.json
# Processed: 2023\202302686 -> JsonFile\2023\202302686.json
# Processed: 2023\202302687 -> JsonFile\2023\202302687.json
# Processed: 2023\202302688 -> JsonFile\2023\202302688.json
# Processed: 2023\202302689 -> JsonFile\2023\202302689.json
# Processed: 2023\202302690 -> JsonFile\2023\202302690.json
# Processed: 2023\202302691 -> JsonFile\2023\202302691.json
# Processed: 2023\202302692 -> JsonFile\2023\202302692.json
# Processed: 2023\202302693 -> JsonFile\2023\202302693.json
# Processed: 2023\202302694 -> JsonFile\2023\202302694.json
# Processed: 2023\202302695 -> JsonFile\2023\202302695.json
# Processed: 2023\202302696 -> JsonFile\2023\202302696.json
# Processed: 2023\202302697 -> JsonFile\2023\202302697.json
# Processed: 2023\202302698 -> JsonFile\2023\202302698.json
# Processed: 2023\202302699 -> JsonFile\2023\202302699.json
# Processed: 2023\202302700 -> JsonFile\2023\202302700.json
# Processed: 2023\202302701 -> JsonFile\2023\202302701.json
# Processed: 2023\202302702 -> JsonFile\2023\202302702.json
# Processed: 2023\202302703 -> JsonFile\2023\202302703.json
# Processed: 2023\202302704 -> JsonFile\2023\202302704.json
# Processed: 2023\202302705 -> JsonFile\2023\202302705.json
# Processed: 2023\202302706 -> JsonFile\2023\202302706.json
# Processed: 2023\202302707 -> JsonFile\2023\202302707.json
# Processed: 2023\202302708 -> JsonFile\2023\202302708.json
# Processed: 2023\202302709 -> JsonFile\2023\202302709.json
# Processed: 2023\202302710 -> JsonFile\2023\202302710.json
# Processed: 2023\202302711 -> JsonFile\2023\202302711.json
# Processed: 2023\202302712 -> JsonFile\2023\202302712.json
# Processed: 2023\202302713 -> JsonFile\2023\202302713.json
# Processed: 2023\202302714 -> JsonFile\2023\202302714.json
# Processed: 2023\202302715 -> JsonFile\2023\202302715.json
# Processed: 2023\202302716 -> JsonFile\2023\202302716.json
# Processed: 2023\202302717 -> JsonFile\2023\202302717.json
# Processed: 2023\202302718 -> JsonFile\2023\202302718.json
# Processed: 2023\202302719 -> JsonFile\2023\202302719.json
# Processed: 2023\202302720 -> JsonFile\2023\202302720.json
# Processed: 2023\202302721 -> JsonFile\2023\202302721.json
# Processed: 2023\202302722 -> JsonFile\2023\202302722.json
# Processed: 2023\202302723 -> JsonFile\2023\202302723.json
# Processed: 2023\202302724 -> JsonFile\2023\202302724.json
# Processed: 2023\202302725 -> JsonFile\2023\202302725.json
# Processed: 2023\202302726 -> JsonFile\2023\202302726.json
# Processed: 2023\202302727 -> JsonFile\2023\202302727.json
# Processed: 2023\202302728 -> JsonFile\2023\202302728.json
# Processed: 2023\202302729 -> JsonFile\2023\202302729.json
# Processed: 2023\202302730 -> JsonFile\2023\202302730.json
# Processed: 2023\202302731 -> JsonFile\2023\202302731.json
# Processed: 2023\202302732 -> JsonFile\2023\202302732.json
# Processed: 2023\202302733 -> JsonFile\2023\202302733.json
# Processed: 2023\202302734 -> JsonFile\2023\202302734.json
# Processed: 2023\202302735 -> JsonFile\2023\202302735.json
# Processed: 2023\202302736 -> JsonFile\2023\202302736.json
# Processed: 2023\202302737 -> JsonFile\2023\202302737.json
# Processed: 2023\202302738 -> JsonFile\2023\202302738.json
# Processed: 2023\202302739 -> JsonFile\2023\202302739.json
# Processed: 2023\202302740 -> JsonFile\2023\202302740.json
# Processed: 2023\202302741 -> JsonFile\2023\202302741.json
# Processed: 2023\202302742 -> JsonFile\2023\202302742.json
# Processed: 2023\202302743 -> JsonFile\2023\202302743.json
# Processed: 2023\202302744 -> JsonFile\2023\202302744.json
# Processed: 2023\202302745 -> JsonFile\2023\202302745.json
# Processed: 2023\202302746 -> JsonFile\2023\202302746.json
# Processed: 2023\202302747 -> JsonFile\2023\202302747.json
# Processed: 2023\202302748 -> JsonFile\2023\202302748.json
# Processed: 2023\202302749 -> JsonFile\2023\202302749.json
# Processed: 2023\202302750 -> JsonFile\2023\202302750.json
# Processed: 2023\202302751 -> JsonFile\2023\202302751.json
# Processed: 2023\202302752 -> JsonFile\2023\202302752.json
# Processed: 2023\202302753 -> JsonFile\2023\202302753.json
# Processed: 2023\202302754 -> JsonFile\2023\202302754.json
# Processed: 2023\202302755 -> JsonFile\2023\202302755.json
# Processed: 2023\202302756 -> JsonFile\2023\202302756.json
# Processed: 2023\202302757 -> JsonFile\2023\202302757.json
# Processed: 2023\202302758 -> JsonFile\2023\202302758.json
# Processed: 2023\202302759 -> JsonFile\2023\202302759.json
# Processed: 2023\202302760 -> JsonFile\2023\202302760.json
# Processed: 2023\202302761 -> JsonFile\2023\202302761.json
# Processed: 2023\202302762 -> JsonFile\2023\202302762.json
# Processed: 2023\202302763 -> JsonFile\2023\202302763.json
# Processed: 2023\202302764 -> JsonFile\2023\202302764.json
# Processed: 2023\202302765 -> JsonFile\2023\202302765.json
# Processed: 2023\202302766 -> JsonFile\2023\202302766.json
# Processed: 2023\202302767 -> JsonFile\2023\202302767.json
# Processed: 2023\202302768 -> JsonFile\2023\202302768.json
# Processed: 2023\202302769 -> JsonFile\2023\202302769.json
# Processed: 2023\202302770 -> JsonFile\2023\202302770.json
# Processed: 2023\202302771 -> JsonFile\2023\202302771.json
# Processed: 2023\202302772 -> JsonFile\2023\202302772.json
# Processed: 2023\202302773 -> JsonFile\2023\202302773.json
# Processed: 2023\202302774 -> JsonFile\2023\202302774.json
# Processed: 2023\202302775 -> JsonFile\2023\202302775.json
# Processed: 2023\202302776 -> JsonFile\2023\202302776.json
# Processed: 2023\202302777 -> JsonFile\2023\202302777.json
# Processed: 2023\202302778 -> JsonFile\2023\202302778.json
# Processed: 2023\202302779 -> JsonFile\2023\202302779.json
# Processed: 2023\202302780 -> JsonFile\2023\202302780.json
# Processed: 2023\202302781 -> JsonFile\2023\202302781.json
# Processed: 2023\202302782 -> JsonFile\2023\202302782.json
# Processed: 2023\202302783 -> JsonFile\2023\202302783.json
# Processed: 2023\202302784 -> JsonFile\2023\202302784.json
# Processed: 2023\202302785 -> JsonFile\2023\202302785.json
# Processed: 2023\202302786 -> JsonFile\2023\202302786.json
# Processed: 2023\202302787 -> JsonFile\2023\202302787.json
# Processed: 2023\202302788 -> JsonFile\2023\202302788.json
# Processed: 2023\202302789 -> JsonFile\2023\202302789.json
# Processed: 2023\202302790 -> JsonFile\2023\202302790.json
# Processed: 2023\202302791 -> JsonFile\2023\202302791.json
# Processed: 2023\202302792 -> JsonFile\2023\202302792.json
# Processed: 2023\202302793 -> JsonFile\2023\202302793.json
# Processed: 2023\202302794 -> JsonFile\2023\202302794.json
# Processed: 2023\202302795 -> JsonFile\2023\202302795.json
# Processed: 2023\202302796 -> JsonFile\2023\202302796.json
# Processed: 2023\202302797 -> JsonFile\2023\202302797.json
# Processed: 2023\202302798 -> JsonFile\2023\202302798.json
# Processed: 2023\202302799 -> JsonFile\2023\202302799.json
# Processed: 2023\202302800 -> JsonFile\2023\202302800.json
# Processed: 2023\202302801 -> JsonFile\2023\202302801.json
# Processed: 2023\202302802 -> JsonFile\2023\202302802.json
# Processed: 2023\202302803 -> JsonFile\2023\202302803.json
# Processed: 2023\202302804 -> JsonFile\2023\202302804.json
# Processed: 2023\202302805 -> JsonFile\2023\202302805.json
# Processed: 2023\202302806 -> JsonFile\2023\202302806.json
# Processed: 2023\202302807 -> JsonFile\2023\202302807.json
# Processed: 2023\202302808 -> JsonFile\2023\202302808.json
# Processed: 2023\202302809 -> JsonFile\2023\202302809.json
# Processed: 2023\202302810 -> JsonFile\2023\202302810.json
# Processed: 2023\202302811 -> JsonFile\2023\202302811.json
# Processed: 2023\202302812 -> JsonFile\2023\202302812.json
# Processed: 2023\202302813 -> JsonFile\2023\202302813.json
# Processed: 2023\202302814 -> JsonFile\2023\202302814.json
# Processed: 2023\202302815 -> JsonFile\2023\202302815.json
# Processed: 2023\202302816 -> JsonFile\2023\202302816.json
# Processed: 2023\202302817 -> JsonFile\2023\202302817.json
# Processed: 2023\202302818 -> JsonFile\2023\202302818.json
# Processed: 2023\202302819 -> JsonFile\2023\202302819.json
# Processed: 2023\202302820 -> JsonFile\2023\202302820.json
# Processed: 2023\202302821 -> JsonFile\2023\202302821.json
# Processed: 2023\202302822 -> JsonFile\2023\202302822.json
# Processed: 2023\202302823 -> JsonFile\2023\202302823.json
# Processed: 2023\202302824 -> JsonFile\2023\202302824.json
# Processed: 2023\202302825 -> JsonFile\2023\202302825.json
# Processed: 2023\202302826 -> JsonFile\2023\202302826.json
# Processed: 2023\202302827 -> JsonFile\2023\202302827.json
# Processed: 2023\202302828 -> JsonFile\2023\202302828.json
# Processed: 2023\202302829 -> JsonFile\2023\202302829.json
# Processed: 2023\202302830 -> JsonFile\2023\202302830.json
# Processed: 2023\202302831 -> JsonFile\2023\202302831.json
# Processed: 2023\202302832 -> JsonFile\2023\202302832.json
# Processed: 2023\202302833 -> JsonFile\2023\202302833.json
# Processed: 2023\202302834 -> JsonFile\2023\202302834.json
# Processed: 2023\202302835 -> JsonFile\2023\202302835.json
# Processed: 2023\202302836 -> JsonFile\2023\202302836.json
# Processed: 2023\202302837 -> JsonFile\2023\202302837.json
# Processed: 2023\202302838 -> JsonFile\2023\202302838.json
# Processed: 2023\202302839 -> JsonFile\2023\202302839.json
# Processed: 2023\202302840 -> JsonFile\2023\202302840.json
# Processed: 2023\202302841 -> JsonFile\2023\202302841.json
# Processed: 2023\202302842 -> JsonFile\2023\202302842.json
# Processed: 2023\202302843 -> JsonFile\2023\202302843.json
# Processed: 2023\202302844 -> JsonFile\2023\202302844.json
# Processed: 2023\202302845 -> JsonFile\2023\202302845.json
# Processed: 2023\202302846 -> JsonFile\2023\202302846.json
# Processed: 2023\202302847 -> JsonFile\2023\202302847.json
# Processed: 2023\202302848 -> JsonFile\2023\202302848.json
# Processed: 2023\202302849 -> JsonFile\2023\202302849.json
# Processed: 2023\202302850 -> JsonFile\2023\202302850.json
# Processed: 2023\202302851 -> JsonFile\2023\202302851.json
# Processed: 2023\202302852 -> JsonFile\2023\202302852.json
# Processed: 2023\202302853 -> JsonFile\2023\202302853.json
# Processed: 2023\202302854 -> JsonFile\2023\202302854.json
# Processed: 2023\202302855 -> JsonFile\2023\202302855.json
# Processed: 2023\202302856 -> JsonFile\2023\202302856.json
# Processed: 2023\202302857 -> JsonFile\2023\202302857.json
# Processed: 2023\202302858 -> JsonFile\2023\202302858.json
# Processed: 2023\202302859 -> JsonFile\2023\202302859.json
# Processed: 2023\202302860 -> JsonFile\2023\202302860.json
# Processed: 2023\202302861 -> JsonFile\2023\202302861.json
# Processed: 2023\202302862 -> JsonFile\2023\202302862.json
# Processed: 2023\202302863 -> JsonFile\2023\202302863.json
# Processed: 2023\202302864 -> JsonFile\2023\202302864.json
# Processed: 2023\202302865 -> JsonFile\2023\202302865.json
# Processed: 2023\202302866 -> JsonFile\2023\202302866.json
# Processed: 2023\202302867 -> JsonFile\2023\202302867.json
# Processed: 2023\202302868 -> JsonFile\2023\202302868.json
# Processed: 2023\202302869 -> JsonFile\2023\202302869.json
# Processed: 2023\202302870 -> JsonFile\2023\202302870.json
# Processed: 2023\202302871 -> JsonFile\2023\202302871.json
# Processed: 2023\202302872 -> JsonFile\2023\202302872.json
# Processed: 2023\202302873 -> JsonFile\2023\202302873.json
# Processed: 2023\202302874 -> JsonFile\2023\202302874.json
# Processed: 2023\202302875 -> JsonFile\2023\202302875.json
# Processed: 2023\202302876 -> JsonFile\2023\202302876.json
# Processed: 2023\202302877 -> JsonFile\2023\202302877.json
# Processed: 2023\202302878 -> JsonFile\2023\202302878.json
# Processed: 2023\202302879 -> JsonFile\2023\202302879.json
# Processed: 2023\202302880 -> JsonFile\2023\202302880.json
# Processed: 2023\202302881 -> JsonFile\2023\202302881.json
# Processed: 2023\202302882 -> JsonFile\2023\202302882.json
# Processed: 2023\202302883 -> JsonFile\2023\202302883.json
# Processed: 2023\202302884 -> JsonFile\2023\202302884.json
# Processed: 2023\202302885 -> JsonFile\2023\202302885.json
# Processed: 2023\202302886 -> JsonFile\2023\202302886.json
# Processed: 2023\202302887 -> JsonFile\2023\202302887.json
# Processed: 2023\202302888 -> JsonFile\2023\202302888.json
# Processed: 2023\202302889 -> JsonFile\2023\202302889.json

# %%
import dask.bag as db
import dask.dataframe as dd
import pandas as pd
import json
from pandas import json_normalize

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

year_paths = ["2018", "2019", "2020", "2021", "2022", "2023"]

year = year_paths[5]
# Out:
# c:\Users\nongy\anaconda3\envs\dsde-cedt\Lib\site-packages\dask\dataframe\__init__.py:49: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
def flatten_json(file_path):
    # Open and load the JSON file
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    # Define the fields you want to flatten
    fields_to_flatten = [
        'item', 'affiliation', 'coredata', 'idxterms', 
        'language', 'authkeywords', 'subject-areas', 'authors'
    ]
    
    # Create an empty dictionary to store flattened data
    flattened_data = {}
    
    # Retrieve the main response
    response = data.get('abstracts-retrieval-response', {})
    
    # Flatten each specified field
    for field in fields_to_flatten:
        if field in response and response[field] is not None:
            try:
                # Handle different types of data
                if isinstance(response[field], list):
                    # For list fields, flatten the first item or concatenate
                    if response[field]:
                        flattened_field = json_normalize(response[field][0] if response[field] else {})
                elif isinstance(response[field], dict):
                    # For dictionary fields
                    flattened_field = json_normalize(response[field])
                else:
                    # For simple fields, create a single-column DataFrame
                    flattened_field = pd.DataFrame({field: [response[field]]})
                
                # Rename columns to include the field name
                flattened_field.columns = [f"{field}_{col}" for col in flattened_field.columns]
                
                # Update flattened data
                if not flattened_field.empty:
                    flattened_data.update(flattened_field.iloc[0].to_dict())
            
            except Exception as e:
                print(f"Error flattening {field}: {e}")
    
    return pd.DataFrame([flattened_data])

# %%
def process_json_files(input_dir, output_file):
    files = [f"{input_dir}/{file}" for file in os.listdir(input_dir) if file.endswith(".json")]
    
    dataframes = [flatten_json(file) for file in files]
    
    combined_df = pd.concat(dataframes, ignore_index=True)
    
    combined_df.to_csv(output_file, index=False)

# %%
input_dir = f"{destination_base}/{year}"
output_file = f"{year}.csv"

# Process the JSON files
process_json_files(input_dir, output_file)

# %%
df = pd.read_csv(output_file)
print(df.shape)
# Out:
# (3082, 305)
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\597717112.py:2: DtypeWarning: Columns (142,216,223,231,235,236,237,247,248,249,250,252,253,255,256,259,281,282,285,290,300,301,302,304) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("2019.csv")

# %%
filtered_df = df[df['coredata_prism:doi'].notna()]
print(filtered_df.shape)
# Out:
# (2799, 305)

# %%
conference_paper_df = filtered_df[filtered_df['coredata_subtypeDescription'].str.lower() == 'conference paper']
not_conference_paper_df = filtered_df[filtered_df['coredata_subtypeDescription'].str.lower() != 'conference paper']
print(conference_paper_df.shape)
print(not_conference_paper_df.shape)
# Out:
# (138, 292)
# (2678, 292)

# %%
conference_paper_proceeding_df = conference_paper_df[conference_paper_df['coredata_prism:aggregationType'].str.lower() == 'conference proceeding']
conference_paper_not_proceeding_df = conference_paper_df[conference_paper_df['coredata_prism:aggregationType'].str.lower() != 'conference proceeding']
not_conference_paper_proceeding_df = not_conference_paper_df[not_conference_paper_df['coredata_prism:aggregationType'].str.lower() == 'conference proceeding']
not_conference_paper_not_proceeding_df = not_conference_paper_df[not_conference_paper_df['coredata_prism:aggregationType'].str.lower() != 'conference proceeding']
print(conference_paper_proceeding_df.shape)
print(conference_paper_not_proceeding_df.shape)
print(not_conference_paper_proceeding_df.shape)
print(not_conference_paper_not_proceeding_df.shape)
# Out:
# (107, 292)
# (31, 292)
# (4, 292)
# (2674, 292)

# %%
for year in year_paths:
    df = pd.read_csv(f"{year}.csv")
    filtered_df = df[df['coredata_prism:doi'].notna()]

    doi_list = filtered_df['coredata_prism:doi'].tolist()    
    with open(f"{year}_ExistDoi.txt", 'w') as file:
        for doi in doi_list:
            file.write(f"{doi}\n")

    filtered_df.to_csv(f"{year}_filtered.csv", index=False)
# Out:
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\4024718662.py:2: DtypeWarning: Columns (157,180,182,193,206,233,240,251,258,263,264,265,266,271,275,276,277,278,285,287,291,294,295,296,299,300,301,302,303,304) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{year}.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\4024718662.py:2: DtypeWarning: Columns (142,216,223,231,235,236,237,247,248,249,250,252,253,255,256,259,281,282,285,290,300,301,302,304) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{year}.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\4024718662.py:2: DtypeWarning: Columns (122,188,192,199,200,217,224,231,232,241,266,268,269,270,275,276,296,297,302,303,304,305,306,307,309,310,311,312) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{year}.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\4024718662.py:2: DtypeWarning: Columns (173,206,233,241,243,246,247,248,276,282,283,286,287,288,289,290,291,292,293,296) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{year}.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\4024718662.py:2: DtypeWarning: Columns (39,95,112,113,122,123,136,139,144,149,150,161,169,170,171,191,209,217,225,226,229,230,232,233,235,236,241,243,246,247,248,249,250,251,252,253,254,255,262,263,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{year}.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_13252\4024718662.py:2: DtypeWarning: Columns (147,164,185,191,209,217,218,224,225,260,261,265,266,267,268,276,277,278,280,281,282,283,284,285,286,287,288,289,290,291) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{year}.csv")

# %% [markdown]
# # Extract For Unique AUID

# %%
import pandas as pd
import ast
import json

# %%
df = pd.read_csv("2018_filtered.csv")
df1 = pd.read_csv("2019_filtered.csv")
df2 = pd.read_csv("2020_filtered.csv")
df3 = pd.read_csv("2021_filtered.csv")
df4 = pd.read_csv("2022_filtered.csv")
df5 = pd.read_csv("2023_filtered.csv")

df = pd.concat([df, df1, df2, df3, df4, df5], ignore_index=True)
# Out:
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:1: DtypeWarning: Columns (180,182,193,206,233,240,251,258,263,264,265,266,268,269,271,275,276,277,278,279,285,286,287,291,294,295,296,299,300,304) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("2018_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:2: DtypeWarning: Columns (142,216,223,231,235,236,237,247,248,249,250,252,253,255,256,259,267,279,281,282,284,285,286,289,290,295,296,297,300,302) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("2019_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:3: DtypeWarning: Columns (122,145,188,192,199,200,217,224,231,232,241,266,268,269,270,275,276,296,297,300,302,303,304,305,306,309,310,311,312) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("2020_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:4: DtypeWarning: Columns (173,206,233,241,243,246,247,248,260,276,282,283,286,287,288,289,290,291,292,293,296) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("2021_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:5: DtypeWarning: Columns (161,171,209,217,229,230,232,233,252,262,263,265,266,267,268,269,270,271,272,273,274,275,276,280,281,282) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv("2022_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:6: DtypeWarning: Columns (147,164,185,191,200,201,203,204,209,217,218,224,225,254,260,261,265,266,267,268,276,284,285,286,287,288,289,290,291) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5 = pd.read_csv("2023_filtered.csv")

# %%
df.columns.to_list()
# Out:
# ['item_ait:process-info.ait:status.@state',
#  'item_ait:process-info.ait:status.@type',
#  'item_ait:process-info.ait:status.@stage',
#  'item_ait:process-info.ait:date-delivered.@day',
#  'item_ait:process-info.ait:date-delivered.@timestamp',
#  'item_ait:process-info.ait:date-delivered.@year',
#  'item_ait:process-info.ait:date-delivered.@month',
#  'item_ait:process-info.ait:date-sort.@day',
#  'item_ait:process-info.ait:date-sort.@year',
#  'item_ait:process-info.ait:date-sort.@month',
#  'item_bibrecord.head.author-group',
#  'item_bibrecord.head.citation-title',
#  'item_bibrecord.head.abstracts',
#  'item_bibrecord.head.correspondence.affiliation.country',
#  'item_bibrecord.head.correspondence.affiliation.@country',
#  'item_bibrecord.head.correspondence.affiliation.city',
#  'item_bibrecord.head.correspondence.affiliation.organization',
#  'item_bibrecord.head.correspondence.person.ce:given-name',
#  'item_bibrecord.head.correspondence.person.ce:initials',
#  'item_bibrecord.head.correspondence.person.ce:degrees',
#  'item_bibrecord.head.correspondence.person.ce:surname',
#  'item_bibrecord.head.correspondence.person.ce:indexed-name',
#  'item_bibrecord.head.citation-info.citation-type.@code',
#  'item_bibrecord.head.citation-info.citation-language.@language',
#  'item_bibrecord.head.citation-info.citation-language.@xml:lang',
#  'item_bibrecord.head.source.sourcetitle-abbrev',
#  'item_bibrecord.head.source.website.ce:e-address.$',
#  'item_bibrecord.head.source.website.ce:e-address.@type',
#  'item_bibrecord.head.source.@country',
#  'item_bibrecord.head.source.translated-sourcetitle.@xml:lang',
#  'item_bibrecord.head.source.volisspag.pagerange.@first',
#  'item_bibrecord.head.source.volisspag.pagerange.@last',
#  'item_bibrecord.head.source.@type',
#  'item_bibrecord.head.source.publicationyear.@first',
#  'item_bibrecord.head.source.isbn',
#  'item_bibrecord.head.source.publisher.publishername',
#  'item_bibrecord.head.source.sourcetitle',
#  'item_bibrecord.head.source.@srcid',
#  'item_bibrecord.head.source.publicationdate.month',
#  'item_bibrecord.head.source.publicationdate.year',
#  'item_bibrecord.head.source.publicationdate.date-text.@xfab-added',
#  'item_bibrecord.head.source.publicationdate.date-text.$',
#  'item_bibrecord.head.source.publicationdate.day',
#  'item_bibrecord.head.enhancement.classificationgroup.classifications',
#  'item_bibrecord.item-info.copyright.$',
#  'item_bibrecord.item-info.copyright.@type',
#  'item_bibrecord.item-info.dbcollection',
#  'item_bibrecord.item-info.history.date-created.@day',
#  'item_bibrecord.item-info.history.date-created.@timestamp',
#  'item_bibrecord.item-info.history.date-created.@year',
#  'item_bibrecord.item-info.history.date-created.@month',
#  'item_bibrecord.item-info.itemidlist.itemid',
#  'item_bibrecord.item-info.itemidlist.ce:doi',
#  'item_bibrecord.tail.bibliography.@refcount',
#  'item_bibrecord.tail.bibliography.reference',
#  'affiliation_affiliation-city',
#  'affiliation_@id',
#  'affiliation_affilname',
#  'affiliation_@href',
#  'affiliation_affiliation-country',
#  'coredata_srctype',
#  'coredata_eid',
#  'coredata_prism:coverDate',
#  'coredata_prism:aggregationType',
#  'coredata_prism:url',
#  'coredata_subtypeDescription',
#  'coredata_link',
#  'coredata_prism:isbn',
#  'coredata_prism:publicationName',
#  'coredata_source-id',
#  'coredata_citedby-count',
#  'coredata_subtype',
#  'coredata_prism:pageRange',
#  'coredata_dc:title',
#  'coredata_prism:endingPage',
#  'coredata_openaccess',
#  'coredata_openaccessFlag',
#  'coredata_prism:doi',
#  'coredata_prism:startingPage',
#  'coredata_dc:identifier',
#  'coredata_dc:publisher',
#  'coredata_dc:creator.author',
#  'language_@xml:lang',
#  'subject-areas_subject-area',
#  'authors_author',
#  'item_xocs:meta.xocs:funding-list.@pui-match',
#  'item_xocs:meta.xocs:funding-list.@has-funding-info',
#  'item_xocs:meta.xocs:funding-list.xocs:funding-addon-generated-timestamp',
#  'item_xocs:meta.xocs:funding-list.xocs:funding-addon-type',
#  'item_bibrecord.head.author-group.affiliation.country',
#  'item_bibrecord.head.author-group.affiliation.postal-code',
#  'item_bibrecord.head.author-group.affiliation.@afid',
#  'item_bibrecord.head.author-group.affiliation.@country',
#  'item_bibrecord.head.author-group.affiliation.city',
#  'item_bibrecord.head.author-group.affiliation.organization',
#  'item_bibrecord.head.author-group.affiliation.affiliation-id.@afid',
#  'item_bibrecord.head.author-group.affiliation.affiliation-id.@dptid',
#  'item_bibrecord.head.author-group.affiliation.@dptid',
#  'item_bibrecord.head.author-group.author',
#  'item_bibrecord.head.citation-info.abstract-language.@language',
#  'item_bibrecord.head.citation-info.abstract-language.@xml:lang',
#  'item_bibrecord.head.source.translated-sourcetitle.$',
#  'item_bibrecord.head.source.volisspag.voliss.@volume',
#  'item_bibrecord.head.source.isbn.@level',
#  'item_bibrecord.head.source.isbn.$',
#  'item_bibrecord.head.source.isbn.@type',
#  'item_bibrecord.head.source.isbn.@length',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confpublication.procpartno',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confname',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confcatnumber',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confseriestitle',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.conflocation.@country',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.conflocation.city',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confcode',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confdate.enddate.@day',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confdate.enddate.@year',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confdate.enddate.@month',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confdate.startdate.@day',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confdate.startdate.@year',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confdate.startdate.@month',
#  'item_bibrecord.head.source.issuetitle',
#  'item_bibrecord.head.source.issn',
#  'item_bibrecord.head.source.article-number',
#  'coredata_dc:description',
#  'coredata_prism:volume',
#  'coredata_prism:issn',
#  'coredata_publishercopyright',
#  'coredata_article-number',
#  'idxterms_mainterm',
#  'item_xocs:meta.xocs:funding-list.xocs:funding',
#  'item_xocs:meta.xocs:funding-list.xocs:funding-text',
#  'item_bibrecord.head.correspondence.affiliation.postal-code',
#  'item_bibrecord.head.citation-info.author-keywords.author-keyword',
#  'item_bibrecord.head.source.publicationdate.date-text',
#  'item_bibrecord.head.source.codencode',
#  'item_bibrecord.head.source.issn.$',
#  'item_bibrecord.head.source.issn.@type',
#  'item_bibrecord.head.grantlist.@complete',
#  'item_bibrecord.head.grantlist.grant-text.$',
#  'item_bibrecord.head.grantlist.grant-text.@xml:lang',
#  'item_bibrecord.head.grantlist.grant',
#  'item_bibrecord.item-info.itemidlist.ce:pii',
#  'coredata_pii',
#  'authkeywords_author-keyword',
#  'item_bibrecord.head.correspondence.affiliation.state',
#  'item_bibrecord.head.enhancement.chemicalgroup.chemicals.@source',
#  'item_bibrecord.head.enhancement.chemicalgroup.chemicals.chemical',
#  'item_bibrecord.item-info.external-source',
#  'coredata_pubmed-id',
#  'item_bibrecord.head.author-group.affiliation.affiliation-id',
#  'item_bibrecord.head.citation-info.abstract-language',
#  'item_bibrecord.head.source.volisspag.voliss.@issue',
#  'item_bibrecord.head.source.publisher.ce:e-address.$',
#  'item_bibrecord.head.source.publisher.ce:e-address.@type',
#  'coredata_prism:issueIdentifier',
#  'item_bibrecord.head.correspondence.affiliation.address-part',
#  'item_bibrecord.head.enhancement.chemicalgroup.chemicals',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confnumber',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.conflocation.venue',
#  'item_bibrecord.head.grantlist.grant.grant-acronym',
#  'item_bibrecord.head.grantlist.grant.grant-agency.@iso-code',
#  'item_bibrecord.head.grantlist.grant.grant-agency.$',
#  'item_bibrecord.head.grantlist.grant.grant-agency-id',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.conforganization',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.conftheme',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confsponsors.confsponsor',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confsponsors.@complete',
#  'item_bibrecord.head.source.contributor-group',
#  'item_xocs:meta.xocs:funding-list.xocs:funding.xocs:funding-agency-matched-string',
#  'item_xocs:meta.xocs:funding-list.xocs:funding.xocs:funding-agency-acronym',
#  'item_xocs:meta.xocs:funding-list.xocs:funding.xocs:funding-agency',
#  'item_xocs:meta.xocs:funding-list.xocs:funding.xocs:funding-id',
#  'item_xocs:meta.xocs:funding-list.xocs:funding.xocs:funding-agency-id',
#  'item_xocs:meta.xocs:funding-list.xocs:funding.xocs:funding-agency-country',
#  'item_bibrecord.head.author-group.affiliation.address-part',
#  'item_bibrecord.head.grantlist.grant.grant-id',
#  'item_bibrecord.tail.bibliography.reference.ref-fulltext',
#  'item_bibrecord.tail.bibliography.reference.@id',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-publicationyear.@first',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-title.ref-titletext',
#  'item_bibrecord.tail.bibliography.reference.ref-info.refd-itemidlist.itemid',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-volisspag.voliss.@volume',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-text',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-authors.author',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-authors.et-al',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-sourcetitle',
#  'item_bibrecord.head.source.publisher.affiliation.address-part',
#  'item_bibrecord.head.source.publisher.affiliation.postal-code',
#  'item_bibrecord.head.source.publisher.affiliation.@country',
#  'item_bibrecord.head.source.publisher.affiliation.city',
#  'item_bibrecord.head.related-item.itemid.$',
#  'item_bibrecord.head.related-item.itemid.@idtype',
#  'item_bibrecord.head.related-item.citation-title',
#  'item_bibrecord.head.related-item.ce:pii',
#  'item_bibrecord.head.related-item.@type',
#  'item_bibrecord.head.related-item.citation-info.author-keywords.author-keyword',
#  'item_bibrecord.head.related-item.citation-info.citation-type.@code',
#  'item_bibrecord.head.related-item.citation-info.citation-language.@language',
#  'item_bibrecord.head.related-item.citation-info.citation-language.@xml:lang',
#  'item_bibrecord.head.related-item.citation-info.abstract-language.@language',
#  'item_bibrecord.head.related-item.citation-info.abstract-language.@xml:lang',
#  'item_bibrecord.head.related-item.source.codencode',
#  'item_bibrecord.head.related-item.source.sourcetitle-abbrev',
#  'item_bibrecord.head.related-item.source.@country',
#  'item_bibrecord.head.related-item.source.translated-sourcetitle.$',
#  'item_bibrecord.head.related-item.source.translated-sourcetitle.@xml:lang',
#  'item_bibrecord.head.related-item.source.issn.$',
#  'item_bibrecord.head.related-item.source.issn.@type',
#  'item_bibrecord.head.related-item.source.volisspag.voliss.@volume',
#  'item_bibrecord.head.related-item.source.volisspag.pagerange.@first',
#  'item_bibrecord.head.related-item.source.volisspag.pagerange.@last',
#  'item_bibrecord.head.related-item.source.@type',
#  'item_bibrecord.head.related-item.source.publicationyear.@first',
#  'item_bibrecord.head.related-item.source.publisher.publishername',
#  'item_bibrecord.head.related-item.source.sourcetitle',
#  'item_bibrecord.head.related-item.source.publicationdate.month',
#  'item_bibrecord.head.related-item.source.publicationdate.year',
#  'item_bibrecord.head.related-item.source.publicationdate.day',
#  'item_bibrecord.head.related-item.ce:doi',
#  'item_bibrecord.tail',
#  'item_bibrecord.head.source.contributor-group.contributor.ce:given-name',
#  'item_bibrecord.head.source.contributor-group.contributor.@seq',
#  'item_bibrecord.head.source.contributor-group.contributor.ce:initials',
#  'item_bibrecord.head.source.contributor-group.contributor.ce:surname',
#  'item_bibrecord.head.source.contributor-group.contributor.@role',
#  'item_bibrecord.head.source.contributor-group.contributor.ce:indexed-name',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.confURL',
#  'item_bibrecord.head.correspondence.affiliation.ce:source-text',
#  'item_bibrecord.head.author-group.affiliation.ce:source-text',
#  'item_bibrecord.head.enhancement.chemicalgroup.chemicals.chemical.chemical-name',
#  'item_bibrecord.head.correspondence.affiliation.@affiliation-instance-id',
#  'item_bibrecord.head.correspondence.person.@author-instance-id',
#  'item_bibrecord.head.author-group.affiliation.@affiliation-instance-id',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames',
#  'item_bibrecord.head.enhancement.manufacturergroup.manufacturers.@type',
#  'item_bibrecord.head.enhancement.manufacturergroup.manufacturers.manufacturer',
#  'item_bibrecord.head.author-group.affiliation.state',
#  'item_bibrecord.head.related-item.source.website.ce:e-address.$',
#  'item_bibrecord.head.related-item.source.website.ce:e-address.@type',
#  'item_bibrecord.head.related-item.source.volisspag.voliss.@issue',
#  'item_bibrecord.head.related-item.source.publicationdate.date-text',
#  'item_bibrecord.head.related-item.source.publisher.ce:e-address.$',
#  'item_bibrecord.head.related-item.source.publisher.ce:e-address.@type',
#  'item_bibrecord.head.related-item.source.article-number',
#  'item_bibrecord.head.enhancement.manufacturergroup.manufacturers.manufacturer.@country',
#  'item_bibrecord.head.enhancement.manufacturergroup.manufacturers.manufacturer.$',
#  'item_bibrecord.head.enhancement.sequencebanks.sequencebank.@name',
#  'item_bibrecord.head.enhancement.sequencebanks.sequencebank.@complete',
#  'item_bibrecord.head.enhancement.sequencebanks.sequencebank.sequence-number',
#  'item_bibrecord.head.correspondence.affiliation.organization.$',
#  'item_bibrecord.head.author-group.affiliation.organization.$',
#  'item_bibrecord.head.source.preferred-sourcetitle',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames.trademanuitem.tradename',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames.trademanuitem.manufacturer.@country',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames.trademanuitem.manufacturer.$',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames.@type',
#  'item_bibrecord.head.related-item.source.issn',
#  'item_bibrecord.head.source.website',
#  'item_bibrecord.head.source.website.websitename',
#  'item_xocs:meta.xocs:funding-list.xocs:funding-source-document.@source-document-type',
#  'item_xocs:meta.xocs:funding-list.xocs:funding-source-document.$',
#  'item_bibrecord.head.enhancement.chemicalgroup.chemicals.chemical.cas-registry-number',
#  'item_bibrecord.head.source.part',
#  'item_bibrecord.head.related-item.source.publisher.affiliation.address-part',
#  'item_bibrecord.head.related-item.source.publisher.affiliation.postal-code',
#  'item_bibrecord.head.related-item.source.publisher.affiliation.@country',
#  'item_bibrecord.head.related-item.source.publisher.affiliation.city',
#  'item_bibrecord.head.source.additional-srcinfo.conferenceinfo.confevent.conflocation.state',
#  'item_bibrecord.head.source.contributor-group.contributor.ce:degrees',
#  'item_bibrecord.item-info.itemidlist.ce:ern',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames.trademanuitem',
#  'item_bibrecord.head.enhancement.manufacturergroup.manufacturers',
#  'item_bibrecord.head.source.volisspag.supplement',
#  'item_bibrecord.tail.bibliography.reference.ref-info.refd-itemidlist.itemid.$',
#  'item_bibrecord.tail.bibliography.reference.ref-info.refd-itemidlist.itemid.@idtype',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-volisspag.pagerange.@first',
#  'item_bibrecord.head.enhancement.sequencebanks.sequencebank.sequence-number.$',
#  'item_bibrecord.head.enhancement.sequencebanks.sequencebank.sequence-number.@type',
#  'item_bibrecord.head.grantlist.grant.grant-agency',
#  'item_bibrecord.head.correspondence',
#  'item_bibrecord.head.source.volumetitle',
#  'item_bibrecord.head.citation-info.author-keywords.author-keyword.$',
#  'item_bibrecord.head.citation-info.author-keywords.author-keyword.@xml:lang',
#  'authkeywords_author-keyword.@_fa',
#  'authkeywords_author-keyword.$',
#  'item_bibrecord.head.source.publisher.affiliation.state',
#  'item_bibrecord.head.correspondence.person.ce:suffix',
#  'item_bibrecord.head.author-group.affiliation.@date-locked',
#  'item_bibrecord.head.author-group.affiliation.ce:text',
#  'item_bibrecord.head.enhancement.chemicalgroup.chemicals.chemical.enzyme-commission-number',
#  'item_bibrecord.head.source.additional-srcinfo.reportinfo.reportnumber',
#  'item_bibrecord.head.enhancement.tradenamegroup.tradenames.trademanuitem.manufacturer',
#  'item_bibrecord.head.source.volisspag.pagecount.$',
#  'item_bibrecord.head.source.volisspag.pagecount.@type',
#  'idxterms_mainterm.$',
#  'idxterms_mainterm.@weight',
#  'idxterms_mainterm.@candidate',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-volisspag.voliss.@issue',
#  'item_bibrecord.tail.bibliography.reference.ref-info.ref-volisspag.pagerange.@last',
#  'item_bibrecord.head.citation-info.citation-language',
#  'item_bibrecord.head.related-item.ce:ern',
#  'item_bibrecord.head.enhancement.descriptorgroup.descriptors.@controlled',
#  'item_bibrecord.head.enhancement.descriptorgroup.descriptors.@type',
#  'item_bibrecord.head.enhancement.descriptorgroup.descriptors.descriptor',
#  'item_bibrecord.head.source.contributor-group.affiliation.@affiliation-instance-id']

# %%
df['authors_author'].head()

authors_str = df['authors_author'][0]
authors_list = ast.literal_eval(authors_str)

for author in authors_list:
    print(author['@auid'])
# Out:
# 14720203700
# 36729660500

# %%
unique_auids = set()

for authors_str in df['authors_author']:
    authors_list = ast.literal_eval(authors_str)
    unique_auids.update(author['@auid'] for author in authors_list)

print(unique_auids)
# Out:
# {'7004647768', '57426800000', '55203914300', '35995743800', '57110088700', '57213864104', '56448183900', '55307591400', '57190949354', '35226917700', '57202752714', '56233925800', '25622931500', '35278294700', '57202775965', '17135681200', '35227389000', '58455172200', '53663248100', '35724515700', '57196369696', '15519120100', '57196087907', '55699406100', '35512093800', '36491917200', '57205247792', '6602097382', '56424384400', '55070886200', '57190983899', '57203589795', '57200209205', '57219465287', '57203666253', '6506917428', '57201474773', '8509602000', '22996761700', '56141261800', '57188998974', '57204540788', '57204277152', '36617456800', '57189264990', '54897929800', '35222026500', '57195533660', '7003602816', '7402838898', '36766757100', '36247374800', '6701780843', '55325142600', '16686836100', '57203194972', '57200559801', '56272419200', '55286336800', '55819700200', '6602158406', '57204324910', '58411652900', '57203667337', '57201551747', '55934588500', '55794330300', '35228246800', '6507261975', '6507700890', '14634899700', '6603412901', '55580069400', '55418940200', '57215476043', '16246113200', '57207901472', '57188858402', '58432946600', '55430486400', '57203022406', '58433164100', '57205115224', '16647024000', '54895455500', '57194522343', '15022540700', '7801644453', '35309175900', '57008245900', '6603914023', '25027672000', '9846166700', '24346774400', '55606666500', '56978556200', '57201491110', '7006316549', '57202728994', '55286579600', '55514443500', '16229582700', '35228127900', '15756384900', '6603726539', '55633950300', '56496474400', '57207905650', '55263498500', '13613798500', '57189846996', '25929529700', '56526973000', '57218494838', '36555082000', '57063481800', '56592664100', '57220647066', '36876232200', '57194864874', '56519253000', '56682015600', '57205244227', '7203021858', '7801593639', '6506821122', '57190068644', '6603199035', '6602690902', '15843258100', '56993980800', '57189270386', '56681908500', '7102263841', '36483561300', '55569782000', '14044221800', '56085491100', '57215430310', '57193236408', '57201999861', '57200789225', '22989437900', '6507951672', '23007504400', '55516699300', '55643799600', '16043724200', '7003575824', '16246475500', '35228229300', '35227010100', '57204037003', '57203679137', '57219643416', '58459006400', '56497670300', '57202570285', '54882040600', '57220662278', '6504761317', '57195404626', '57192809939', '57215882789', '56903732500', '6603683954', '55866389000', '57195241377', '58375463100', '57211450956', '57216596836', '55888739700', '56191827000', '56507109700', '38861144300', '7003342181', '7801571965', '57189994571', '54973936100', '58377689300', '37007697400', '56973660200', '56074057800', '47562239900', '35277955900', '56032831800', '23988979800', '6507606180', '35308923600', '56607299100', '7003325051', '24757769500', '56206275700', '57211721692', '15833772800', '57204897344', '56198607900', '45161458000', '36723697500', '57213879237', '35821822600', '15831205700', '56024582900', '57189751409', '57214699347', '6602510813', '7003394845', '57195552309', '58462429400', '56681856800', '57214339223', '56394653400', '58464174200', '6701618960', '57223942459', '47961360200', '35227613100', '7801599131', '58433805100', '24437671400', '35277920200', '36122805600', '7005154064', '22834750900', '22833394800', '57192980685', '55547103616', '57202059352', '57200823378', '56317712500', '57194632445', '8912180500', '57203429692', '57192305828', '7401527569', '55879800100', '12765683100', '19836678400', '36696335300', '6506404916', '8086252800', '55324535000', '58095462200', '57203392644', '56682028900', '57203687964', '56311989200', '46161770700', '7103053763', '57218441126', '57204191364', '6603699915', '7102703833', '55441008100', '55659798100', '57200277356', '36492316100', '56205693400', '8773530700', '37665398200', '7101638297', '35362095700', '58095307700', '56784368200', '56814506500', '57192663316', '57195244975', '57207898247', '57202781016', '5720138 ...

# %%
df['authors_author'] = df['authors_author'].apply(ast.literal_eval)

# Extract all `@auid` values from the column
all_auids = set(auid for authors_list in df['authors_author'] for auid in [author['@auid'] for author in authors_list])

# Display the unique auid values
print(all_auids)
# Out:
# {'58395294900', '57554776500', '57219159683', '57211459276', '58177098400', '57219756466', '57214717287', '57222326099', '35069899200', '55307591400', '57221115737', '44061910800', '7403579470', '55909975200', '8355886600', '57202775965', '57221519528', '57221940786', '56818975700', '57209788526', '57723378300', '53663248100', '24073584900', '35724515700', '57195991104', '57196369696', '57196087907', '55699406100', '55043180700', '35512093800', '8263937200', '58366575100', '57985990700', '12779951100', '57218794371', '58031293700', '57193256081', '6701584602', '57203589795', '57200209205', '57219465287', '8509602000', '56244757300', '7004039968', '57214535465', '56026053700', '57203640779', '57292914300', '56978608700', '57201446591', '57189264990', '54897929800', '56437690000', '35222026500', '6602624567', '57311509500', '58109474000', '6507684871', '55212537400', '6701780843', '57214235808', '24435957400', '6603443460', '55883596100', '58507255100', '58365753100', '57207981344', '58174511400', '57200559801', '57221064849', '23059448900', '57220738106', '37661608200', '57209775294', '57213860683', '57480846300', '57200119327', '57201368480', '8080680100', '55316015400', '55794330300', '57225075090', '57574513500', '57208237541', '14634899700', '23996029300', '6603412901', '57222475528', '6603732162', '22937422100', '57852308000', '6507816542', '58260030600', '57216593479', '57557111700', '57190818365', '54585517800', '26024445400', '57216978825', '57221952365', '58189051800', '7202750694', '57151227100', '6507728608', '35309175900', '57217062630', '57211980541', '57216943310', '57201491110', '57204515592', '7103299061', '14060929900', '57465221800', '55286579600', '55655848500', '16203199900', '56766211400', '6505781844', '57195957064', '15756384900', '57189846996', '57205766144', '56545793100', '58203015800', '57203321249', '58247380300', '57194210011', '58503104900', '57212678912', '55747525200', '57206713159', '56964424700', '55662711400', '56300837300', '55957581300', '23089083400', '57226723849', '57209136159', '57986520000', '7801593639', '6506821122', '8569077100', '9337757500', '6602690902', '57371448100', '25645542000', '57219643209', '24468605200', '55936658000', '7401726561', '35393575200', '57206945529', '57211374249', '57211506230', '7006400138', '56681908500', '7102263841', '54883747400', '57963918900', '55569782000', '55768289200', '57193489996', '7003360137', '57200014460', '14044221800', '58368384800', '57205684848', '57218300703', '57189764625', '58092216200', '55553159100', '57200789225', '57223883964', '58397988500', '56147299000', '6507951672', '57204452709', '55917075900', '25651661800', '55516699300', '15041663800', '7003575824', '35587272900', '55959858100', '23006918000', '6603175612', '58021674900', '26652648800', '57208461282', '57204037003', '58459006400', '55159781000', '23669184200', '35572862100', '58443743100', '58258131100', '57205595615', '54882040600', '6504761317', '36624932600', '6603683954', '57206770270', '56344439500', '13409602000', '56073010700', '14019341800', '55577346500', '55668722900', '58310418800', '57779990600', '57196195083', '35381812400', '57203258271', '57195241377', '56465099900', '58463421600', '57827985000', '57216596836', '55888739700', '7102328975', '57205328273', '57190392987', '57204628063', '57224634955', '25423432200', '56070815500', '38861144300', '7005750885', '6506850648', '57221924083', '57200695466', '24067209500', '58177585700', '57189994571', '7801571965', '14017045200', '57219640154', '57202205586', '58482287500', '23988979800', '24074968600', '57223917395', '57209095521', '55703953400', '57204674279', '8445135400', '6603131513', '57211721692', '58396658200', '58544654500', '57201310934', '58464350800', '24471351900', '57374113400', '58367548100', '57213879237', '57224111965', '57196317673', '7003960538', '57873817500', '57195552309', '57212785087', '58428472800', '56065994500', '57204421420', '6603029548', '36080819300', '57223942459', '7801591529', '5722 ...

# %%
auid_list = [{"@auid": auid} for auid in all_auids]
print(len(auid_list))

# Write the list to a JSON file
with open("auid_list_exist_data.json", "w") as file:
    json.dump(auid_list, file, indent=4)

print("File written successfully: auid_list_exist_data.json")
# Out:
# 72401
# File written successfully: auid_list_exist_data.json

# %%
DIRECTORY = "JsonFile_Scrape"
YEAR = ["2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
FILENAME = {"2013":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2014":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2015":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2016":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2017":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2018":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2018":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2019":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2020":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2021":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2022":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2023":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"]}

# %%
authors_set = set()

for year in YEAR:
    for filename in FILENAME[year]:
        print(f"Processing {year}_{filename}.json")
        with open(f"{DIRECTORY}/{year}/{year}_{filename}.json") as file:
            data = json.load(file)

        for paper in data:
            author = paper.get('author', [])
            if len(author) > 0:
                for a in author:
                    auid = a.get('@auid', None)
                    if auid is not None:
                        authors_set.add(auid)

print(len(authors_set))
print(authors_set)
# Out:
# Processing 2013_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2013_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2013_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2013_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2014_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2014_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2014_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2014_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2015_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2015_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2015_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2015_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2016_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2016_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2016_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2016_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2017_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2017_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2017_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2017_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2018_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2018_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2018_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2019_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2019_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2019_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2020_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2020_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2020_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2021_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2021_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2021_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2022_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2022_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2022_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2023_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2023_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2023_not_conference_paper_proceeding_fetchContentAbstract.json
# 37771
# {'54967048000', '58087456200', '56101585900', '57205882972', '14008240700', '54580928900', '57104812100', '57202254977', '6506771004', '59115181700', '55979132300', '57188663721', '56221714400', '55898477300', '57204962785', '16645423700', '7403501840', '56646638300', '6508235439', '6602621026', '57021815400', '7409387613', '26422340000', '36006406400', '57188644090', '57218684877', '54082869100', '59093168600', '57220269273', '6507244609', '36700472600', '7006639903', '55658275300', '54403043100', '55210805100', '57196462030', '23986247700', '23569224200', '55366251000', '56132521800', '57193137783', '56814029200', '57201277296', '58743141300', '7403234771', '55869702100', '57211396608', '57062055300', '58770299800', '57013804800', '55736450500', '6602885046', '55889245900', '56269618600', '57194343423', '6603867335', '12792362600', '36609424700', '57205393061', '55747946800', '57193026313', '57908537100', '6602836151', '6507088349', '56815042800', '33267892500', '7401777066', '57193156798', '6507907326', '35219973300', '56926343300', '56725955900', '57861111500', '58715232200', '55969183900', '57200099971', '6602882785', '57196117927', '24734168300', '55484838400', '6603431564', '57215929427', '13612265200', '57203725185', '57223035534', '6602212129', '55975647800', '56076756300', '16239345700', '16308679400', '57210232489', '57195579272', '57189027444', '57831193800', '9275689800', '57214990657', '6506868925', '6603028415', '57225273546', '55203612600', '57202194471', '57201312378', '57191355178', '57203388659', '22978837900', '54413233600', '57215670579', '57193135309', '55817674600', '53983959000', '57193754914', '57197115703', '24468984100', '7004746450', '58075225200', '7004538107', '57221994663', '10340424400', '36136365500', '57213074537', '57205580161', '55948522400', '6603546268', '8574872000', '52963513700', '56899018000', '57219325126', '7004225020', '57213155616', '57191032092', '35247657400', '57189519082', '55173603700', '14324455200', '57220784505', '22835020500', '57211049825', '12445625700', '55617336900', '57193137219', '57221534768', '57189520015', '57193313368', '57202193763', '15025974300', '58257352000', '58102132100', '7004139386', '7103386012', '55939316400', '8156746000', '7004646932', '58146835600', '57222630151', '7005907326', '55976223800', '8987563200', '35952572900', '7102376433', '55711199400', '36971066600', '56568474100', '6701368022', '56601169900', '56296911200', '57201736684', '57192990989', '57219547477', '57221874327', '57222487822', '57552274200', '57188746620', '59287372300', '57216738574', '55750120500', '55365937600', '36781966700', '54982705800', '57196405458', '7203075961', '57193140539', '6507816811', '57200135449', '57205158087', '59169501700', '58318408100', '55702521818', '36132802000', '6603573670', '57225075291', '7403613419', '57058538500', '58029521600', '57216298317', '57190981654', '56151107900', '59168966100', '57193165794', '34770593700', '57193094545', '57826937500', '57216755685', '57193257908', '57200090039', '57188650150', '7006153134', '57209126020', '57211053654', '55552049200', '55958984800', '6603450996', '54955865000', '57204496592', '56682083000', '55320192900', '23013614400', '14007880800', '6602223122', '55948914700', '57194719151', '56919681400', '56113062800', '57191717386', '55871494100', '58069412600', '26422534800', '24172097700', '36625205800', '55280060200', '57189029562', '57200089559', '57326283600', '56458889300', '57220087641', '55975806900', '55508186800', '7003393897', '6602590709', '35239881400', '58147356400', '57202685502', '6507556341', '50861605100', '16429273900', '35223939200', '16745117200', '6506681303', '57217055050', '57189471947', '6604095327', '55436449900', '59038856500', '14021930100', '57194261987', '57204221943', '24401750500', '57188929737', '57206260352', '56609746200', '8320355200', '25649793900', '55830039100', '36753080800', '54917476500', '6701605062', '58295684000', '55611671200', '56967374900', '25522989100', '5718899196 ...

# %%
result_set = all_auids | authors_set
print(len(result_set))
# Out:
# 109883

# %%
all_auid_list = [{"@auid": auid} for auid in result_set]
print(len(all_auid_list))

# Write the list to a JSON file
with open("all_auid_list.json", "w") as file:
    json.dump(all_auid_list, file, indent=4)

print("File written successfully: all_auid_list.json")
# Out:
# 109883
# File written successfully: all_auid_list.json

# %% [markdown]
# # Extract for unique AFF-ID

# %%
import pandas as pd
import ast
import json

# %%
df = pd.read_csv("2018_filtered.csv")
df1 = pd.read_csv("2019_filtered.csv")
df2 = pd.read_csv("2020_filtered.csv")
df3 = pd.read_csv("2021_filtered.csv")
df4 = pd.read_csv("2022_filtered.csv")
df5 = pd.read_csv("2023_filtered.csv")

df = pd.concat([df, df1, df2, df3, df4, df5], ignore_index=True)
# Out:
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:1: DtypeWarning: Columns (180,182,193,206,233,240,251,258,263,264,265,266,268,269,271,275,276,277,278,279,285,286,287,291,294,295,296,299,300,304) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("2018_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:2: DtypeWarning: Columns (142,216,223,231,235,236,237,247,248,249,250,252,253,255,256,259,267,279,281,282,284,285,286,289,290,295,296,297,300,302) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("2019_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:3: DtypeWarning: Columns (122,145,188,192,199,200,217,224,231,232,241,266,268,269,270,275,276,296,297,300,302,303,304,305,306,309,310,311,312) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("2020_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:4: DtypeWarning: Columns (173,206,233,241,243,246,247,248,260,276,282,283,286,287,288,289,290,291,292,293,296) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("2021_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:5: DtypeWarning: Columns (161,171,209,217,229,230,232,233,252,262,263,265,266,267,268,269,270,271,272,273,274,275,276,280,281,282) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv("2022_filtered.csv")
# C:\Users\nongy\AppData\Local\Temp\ipykernel_44784\1349481222.py:6: DtypeWarning: Columns (147,164,185,191,200,201,203,204,209,217,218,224,225,254,260,261,265,266,267,268,276,284,285,286,287,288,289,290,291) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5 = pd.read_csv("2023_filtered.csv")

# %%
df['authors_author'] = df['authors_author'].apply(ast.literal_eval)

# %%
affiliation_set = set()

for authors_list in df['authors_author']:
    for author in authors_list:
        affiliation = author.get('affiliation', [])

        if type(affiliation) is list:
            for a in affiliation:
                if a.get('@id', None) is not None:
                    affiliation_set.add(a.get('@id'))

print(len(affiliation_set))
# Out:
# 4799

# %%
DIRECTORY = "JsonFile_Scrape"
YEAR = ["2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
FILENAME = {"2013":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2014":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2015":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2016":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2017":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_not_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2018":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2018":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2019":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2020":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2021":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2022":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"],
            "2023":["conference_paper_not_proceeding_fetchContentAbstract", "conference_paper_proceeding_fetchContentAbstract", "not_conference_paper_proceeding_fetchContentAbstract"]}

# %%
affiliation_set_new_data = set()

for year in YEAR:
    for filename in FILENAME[year]:
        print(f"Processing {year}_{filename}.json")
        with open(f"{DIRECTORY}/{year}/{year}_{filename}.json") as file:
            data = json.load(file)

        for paper in data:
            author = paper.get('author', [])
            if len(author) > 0:
                for a in author:
                    affiliation = a.get('affiliation', [])
                    if type(affiliation) is list:
                        for a in affiliation:
                            if a.get('@id', None) is not None:
                                affiliation_set_new_data.add(a.get('@id'))

print(len(affiliation_set_new_data))
# Out:
# Processing 2013_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2013_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2013_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2013_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2014_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2014_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2014_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2014_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2015_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2015_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2015_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2015_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2016_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2016_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2016_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2016_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2017_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2017_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2017_not_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2017_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2018_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2018_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2018_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2019_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2019_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2019_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2020_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2020_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2020_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2021_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2021_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2021_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2022_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2022_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2022_not_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2023_conference_paper_not_proceeding_fetchContentAbstract.json
# Processing 2023_conference_paper_proceeding_fetchContentAbstract.json
# Processing 2023_not_conference_paper_proceeding_fetchContentAbstract.json
# 4045

# %%
result_aff_set = affiliation_set | affiliation_set_new_data
print(len(result_aff_set))
# Out:
# 7625

# %%
all_affid_list = [{"@affid": affid} for affid in result_aff_set]

# Write the list to a JSON file
with open("all_affid_list.json", "w") as file:
    json.dump(all_affid_list, file, indent=4)

print("File written successfully: all_affid_list.json")
# Out:
# File written successfully: all_affid_list.json
