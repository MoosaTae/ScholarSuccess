# %%
import requests
import time
import json

BASE_URL = ""
API_KEY = ""
EXIST_DATA_YEAR = [2018, 2019, 2020, 2021, 2022, 2023]
START_YEAR = 2018
END_YEAR = START_YEAR
NUM_PAPERS = 25
RESULTS_PER_REQUEST = 25
OPTION = 3
doi_list = []

if START_YEAR in EXIST_DATA_YEAR:
    with open(f"{START_YEAR}_ExistDoi.txt", 'r') as file:
        doi_list = file.readlines()
    doi_list = [doi.strip() for doi in doi_list]

# %%
def filter_papers_with_doi(papers, year):
    """
    Filter papers that have a DOI.
    """
    if year in EXIST_DATA_YEAR:
        return [paper for paper in papers if ('prism:doi' in paper and paper['prism:doi'] not in doi_list)]
    
    return [paper for paper in papers if 'prism:doi' in paper]

# %%
def fetch_scopus_data(api_key, start_year, end_year, count, optional_query):
    headers = {
        "X-ELS-APIKey": api_key,
    }

    query = [f"PUBYEAR > {start_year - 1} AND PUBYEAR < {end_year + 1} AND DOCTYPE(cp) AND SRCTYPE(p)", 
             f"PUBYEAR > {start_year - 1} AND PUBYEAR < {end_year + 1} AND DOCTYPE(cp) AND NOT SRCTYPE(p)",
             f"PUBYEAR > {start_year - 1} AND PUBYEAR < {end_year + 1} AND SRCTYPE(p) AND NOT DOCTYPE(cp)", 
             f"PUBYEAR > {start_year - 1} AND PUBYEAR < {end_year + 1} AND NOT (DOCTYPE(cp) AND SRCTYPE(p))"]

    papers = []
    papers_with_doi = []
    start = 0

    while len(papers_with_doi) < count:
        fetch_count = min(RESULTS_PER_REQUEST, count - len(papers))
        params = {
            "query": query[optional_query],
            "start": start,
            "count": fetch_count,
            "field": "prism:url,dc:identifier,eid,dc:title,prism:aggregationType,subtype,subtypeDescription,citedby-count,prism:publicationName,prism:isbn,prism:issn,prism:volume,prism:issueIdentifier,prism:pageRange,prism:coverDate,prism:coverDisplayDate,prism:doi,affiliation,dc:creator,openaccess,openaccessFlag",
        }

        try:
            response = requests.get(BASE_URL, headers=headers, params=params)
            response.raise_for_status()
            data = response.json()

            # Debug: Check total results available
            if start == 0:
                total_results = int(data.get("search-results", {}).get("opensearch:totalResults", 0))
                print(f"Total results available: {total_results}")

            # Extract entries
            entries = data.get("search-results", {}).get("entry", [])
            if not entries:
                print(f"No more entries at start index {start}. Exiting.")
                break

            papers.extend(entries)
            print(f"Fetched {len(entries)} papers starting from index {start}")

            papers_with_doi = filter_papers_with_doi(papers, start_year)

            # Update start for the next page
            start += len(entries)
            time.sleep(1)  # Respect rate limits

        except requests.exceptions.RequestException as e:
            print(f"Error fetching data at start index {start}: {e}")
            break


    # return papers[:count]
    return papers_with_doi[:count]

# %%
def save_to_json(data, filename):
    """
    Save a list of data to a JSON file.
    """
    try:
        with open(filename, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        print(f"Data successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving data: {e}")

# %%
YEAR = [2013, 2014, 2015, 2016, 2017, 2019, 2020, 2021, 2022, 2023]

MAP_YEAR = {
            2013: [0, 1, 2, 3], 
            2014: [0, 1, 2, 3], 
            2015: [0, 1, 2, 3], 
            2016: [0, 1, 2, 3], 
            2017: [0, 1, 2, 3], 
            2019: [0, 1, 2], 
            2020: [0, 1, 2], 
            2021: [0, 1, 2], 
            2022: [0, 1, 2], 
            2023: [0, 1, 2]}
MAP_YEAR_NUM = {
            2013: [1250, 1250, 1250, 1250], 
            2014: [1250, 1250, 1250, 1250], 
            2015: [1250, 1250, 1250, 1250], 
            2016: [1250, 1250, 1250, 1250], 
            2017: [1250, 1250, 1250, 1250], 
            2019: [911, 1188, 1147], 
            2020: [1032, 1168, 1145], 
            2021: [1085, 1224, 1248], 
            2022: [1073, 1227, 1239], 
            2023: [1143, 1219, 1246]}

# %%
if __name__ == "__main__":
    research_papers = fetch_scopus_data(API_KEY, START_YEAR, END_YEAR, NUM_PAPERS, OPTION)
    print(f"Total papers fetched: {len(research_papers)}")

    # Check if data was fetched successfully
    if research_papers:
        print(f"Fetched {len(research_papers)} papers successfully.")
        
        if OPTION == 0:
            save_to_json(research_papers, f"{START_YEAR}_conference_paper_proceeding.json")
        elif OPTION == 1:
            save_to_json(research_papers, f"{START_YEAR}_conference_paper_not_proceeding.json")
        elif OPTION == 2:
            save_to_json(research_papers, f"{START_YEAR}_not_conference_paper_proceeding.json")
        elif OPTION == 3:
            save_to_json(research_papers, f"{START_YEAR}_not_conference_paper_not_proceeding.json")
    else:
        print("Failed to fetch research papers.")
# Out:
# Total results available: 2893725
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Total papers fetched: 25
# Fetched 25 papers successfully.
# Data successfully saved to 2018_not_conference_paper_not_proceeding.json

# %%
for year in YEAR:
    for option in MAP_YEAR[year]:
        print(f"Fetching data for year {year} with option {option}")

        num_papers = MAP_YEAR_NUM[year][option]
        research_papers = fetch_scopus_data(API_KEY, year, year, num_papers, option)
        print(f"Total papers fetched: {len(research_papers)}")

        # Check if data was fetched successfully
        if research_papers:
            print(f"Fetched {len(research_papers)} papers successfully.")
            
            if option == 0:
                save_to_json(research_papers, f"{year}_conference_paper_proceeding.json")
            elif option == 1:
                save_to_json(research_papers, f"{year}_conference_paper_not_proceeding.json")
            elif option == 2:
                save_to_json(research_papers, f"{year}_not_conference_paper_proceeding.json")
            elif option == 3:
                save_to_json(research_papers, f"{year}_not_conference_paper_not_proceeding.json")
        else:
            print("Failed to fetch research papers.")
# Out:
# Fetching data for year 2013 with option 0
# Total results available: 358534
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Fetched 25 papers starting from index 1500
# Fetched 25 papers starting from index 1525
# Fetched 25 papers starting from index 1550
# Fetched 25 papers starting from index 1575
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2013_conference_paper_proceeding.json
# Fetching data for year 2013 with option 1
# Total results available: 142404
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Fetched 25 papers starting from index 1500
# Fetched 25 papers starting from index 1525
# Fetched 25 papers starting from index 1550
# Fetched 25 papers starting from index 1575
# Fetched 25 papers starting from index 1600
# Fetched 25 papers starting from index 1625
# Fetched 25 papers starting from index 1650
# Fetched 25 papers starting from index 1675
# Fetched 25 papers starting from index 1700
# Fetched 25 papers starting from index 1725
# Fetched 25 papers starting from index 1750
# Fetched 25 papers starting from index 1775
# Fetched 25 papers starting from index 1800
# Fetched 25 papers starting from index 1825
# Fetched 25 papers starting from index 1850
# Fetched 25 papers starting from index 1875
# Fetched 25 papers starting from index 1900
# Fetched 25 papers starting from index 1925
# Fetched 25 papers starting from index 1950
# Fetched 25 papers starting from index 1975
# Fetched 25 papers starting from index 2000
# Fetched 25 papers starting from index 2025
# Fetched 25 papers starting from index 2050
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2013_conference_paper_not_proceeding.json
# Fetching data for year 2013 with option 2
# Total results available: 10517
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Fetched 25 papers starting from index 1500
# Fetched 25 papers starting from index 1525
# Fetched 25 papers starting from index 1550
# Fetched 25 papers starting from index 1575
# Fetched 25 papers starting from index 1600
# Fetched 25 papers starting from index 1625
# Fetched 25 papers starting from index 1650
# Fetched 25 papers starting from index 1675
# Fetched 25 papers starting from index 1700
# Fetched 25 papers starting from index 1725
# Fetched 25 papers starting from index 1750
# Fetched 25 papers starting from index 1775
# Fetched 25 papers starting from index 1800
# Fetched 25 papers starting from index 1825
# Fetched 25 papers starting from index 1850
# Fetched 25 papers starting from index 1875
# Fetched 25 papers starting from index 1900
# Fetched 25 papers starting from index 1925
# Fetched 25 papers starting from index 1950
# Fetched 25 papers starting from index 1975
# Fetched 25 papers starting from index 2000
# Fetched 25 papers starting from index 2025
# Fetched 25 papers starting from index 2050
# Fetched 25 papers starting from index 2075
# Fetched 25 papers starting from index 2100
# Fetched 25 papers starting from index 2125
# Fetched 25 papers starting from index 2150
# Fetched 25 papers starting from index 2175
# Fetched 25 papers starting from index 2200
# Fetched 25 papers starting from index 2225
# Fetched 25 papers starting from index 2250
# Fetched 25 papers starting from index 2275
# Fetched 25 papers starting from index 2300
# Fetched 25 papers starting from index 2325
# Fetched 25 papers starting from index 2350
# Fetched 25 papers starting from index 2375
# Fetched 25 papers starting from index 2400
# Fetched 25 papers starting from index 2425
# Fetched 25 papers starting from index 2450
# Fetched 25 papers starting from index 2475
# Fetched 25 papers starting from index 2500
# Fetched 25 papers starting from index 2525
# Fetched 25 papers starting from index 2550
# Fetched 25 papers starting from index 2575
# Fetched 25 papers starting from index 2600
# Fetched 25 papers starting from index 2625
# Fetched 25 papers starting from index 2650
# Fetched 25 papers starting from index 2675
# Fetched 25 papers starting from index 2700
# Fetched 25 papers starting from index 2725
# Fetched 25 papers starting from index 2750
# Fetched 25 papers starting from index 2775
# Fetched 25 papers starting from index 2800
# Fetched 25 papers starting from index 2825
# Fetched 25 papers starting from index 2850
# Fetched 25 papers starting from index 2875
# Fetched 25 papers starting from index 2900
# Fetched 25 papers starting from index 2925
# Fetched 25 papers starting from index 2950
# Fetched 25 papers starting from index 2975
# Fetched 25 papers starting from index 3000
# Fetched 25 papers starting from index 3025
# Fetched 25 papers starting from index 3050
# Fetched 25 papers starting from index 3075
# Fetched 25 papers starting from index 3100
# Fetched 25 papers starting from index 3125
# Fetched 25 papers starting from index 3150
# Fetched 25 papers starting from index 3175
# Fetched 25 papers starting from index 3200
# Fetched 25 papers starting from index 3225
# Fetched 25 papers starting from index 3250
# Fetched 25 papers starting from index 3275
# Fetched 25 papers starting from index 3300
# Fetched 25 papers starting from index 3325
# Fetched 25 papers starting from index 3350
# Fetched 25 papers starting from index 3375
# Fetched 25 papers starting from index 3400
# Fetched 25 papers starting from index 3425
# Fetched 25 papers starting from index 3450
# Fetched 25 papers starting from index 3475
# Fetched 25 papers starting from index 3500
# Fetched 25 papers starting from index 3525
# Fetched 25 papers starting from index 3550
# Fetched 25 papers starting from index 3575
# Fetched 25 papers starting from index 3600
# Fetched 25 papers starting from index 3625
# Fetched 25 papers starting from index 3650
# Fetched 25 papers starting from index 3675
# Fetched 25 papers starting from index 3700
# Fetched 25 papers starting from index 3725
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2013_not_conference_paper_proceeding.json
# Fetching data for year 2013 with option 3
# Total results available: 2584298
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Fetched 25 papers starting from index 1500
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2013_not_conference_paper_not_proceeding.json
# Fetching data for year 2014 with option 0
# Total results available: 361442
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2014_conference_paper_proceeding.json
# Fetching data for year 2014 with option 1
# Total results available: 138390
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2014_conference_paper_not_proceeding.json
# Fetching data for year 2014 with option 2
# Total results available: 9993
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Fetched 25 papers starting from index 1500
# Fetched 25 papers starting from index 1525
# Fetched 25 papers starting from index 1550
# Fetched 25 papers starting from index 1575
# Fetched 25 papers starting from index 1600
# Fetched 25 papers starting from index 1625
# Fetched 25 papers starting from index 1650
# Fetched 25 papers starting from index 1675
# Fetched 25 papers starting from index 1700
# Fetched 25 papers starting from index 1725
# Fetched 25 papers starting from index 1750
# Fetched 25 papers starting from index 1775
# Fetched 25 papers starting from index 1800
# Fetched 25 papers starting from index 1825
# Fetched 25 papers starting from index 1850
# Fetched 25 papers starting from index 1875
# Fetched 25 papers starting from index 1900
# Fetched 25 papers starting from index 1925
# Fetched 25 papers starting from index 1950
# Fetched 25 papers starting from index 1975
# Fetched 25 papers starting from index 2000
# Fetched 25 papers starting from index 2025
# Fetched 25 papers starting from index 2050
# Fetched 25 papers starting from index 2075
# Fetched 25 papers starting from index 2100
# Fetched 25 papers starting from index 2125
# Fetched 25 papers starting from index 2150
# Fetched 25 papers starting from index 2175
# Fetched 25 papers starting from index 2200
# Fetched 25 papers starting from index 2225
# Fetched 25 papers starting from index 2250
# Fetched 25 papers starting from index 2275
# Fetched 25 papers starting from index 2300
# Fetched 25 papers starting from index 2325
# Fetched 25 papers starting from index 2350
# Fetched 25 papers starting from index 2375
# Fetched 25 papers starting from index 2400
# Fetched 25 papers starting from index 2425
# Fetched 25 papers starting from index 2450
# Fetched 25 papers starting from index 2475
# Fetched 25 papers starting from index 2500
# Fetched 25 papers starting from index 2525
# Fetched 25 papers starting from index 2550
# Fetched 25 papers starting from index 2575
# Fetched 25 papers starting from index 2600
# Fetched 25 papers starting from index 2625
# Fetched 25 papers starting from index 2650
# Fetched 25 papers starting from index 2675
# Fetched 25 papers starting from index 2700
# Fetched 25 papers starting from index 2725
# Fetched 25 papers starting from index 2750
# Fetched 25 papers starting from index 2775
# Fetched 25 papers starting from index 2800
# Fetched 25 papers starting from index 2825
# Fetched 25 papers starting from index 2850
# Fetched 25 papers starting from index 2875
# Fetched 25 papers starting from index 2900
# Fetched 25 papers starting from index 2925
# Fetched 25 papers starting from index 2950
# Fetched 25 papers starting from index 2975
# Fetched 25 papers starting from index 3000
# Fetched 25 papers starting from index 3025
# Fetched 25 papers starting from index 3050
# Fetched 25 papers starting from index 3075
# Fetched 25 papers starting from index 3100
# Fetched 25 papers starting from index 3125
# Fetched 25 papers starting from index 3150
# Fetched 25 papers starting from index 3175
# Fetched 25 papers starting from index 3200
# Fetched 25 papers starting from index 3225
# Fetched 25 papers starting from index 3250
# Fetched 25 papers starting from index 3275
# Fetched 25 papers starting from index 3300
# Fetched 25 papers starting from index 3325
# Fetched 25 papers starting from index 3350
# Fetched 25 papers starting from index 3375
# Fetched 25 papers starting from index 3400
# Fetched 25 papers starting from index 3425
# Fetched 25 papers starting from index 3450
# Fetched 25 papers starting from index 3475
# Fetched 25 papers starting from index 3500
# Fetched 25 papers starting from index 3525
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2014_not_conference_paper_proceeding.json
# Fetching data for year 2014 with option 3
# Total results available: 2623581
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2014_not_conference_paper_not_proceeding.json
# Fetching data for year 2015 with option 0
# Total results available: 364200
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2015_conference_paper_proceeding.json
# Fetching data for year 2015 with option 1
# Total results available: 67281
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2015_conference_paper_not_proceeding.json
# Fetching data for year 2015 with option 2
# Total results available: 10196
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Fetched 25 papers starting from index 1500
# Fetched 25 papers starting from index 1525
# Fetched 25 papers starting from index 1550
# Fetched 25 papers starting from index 1575
# Fetched 25 papers starting from index 1600
# Fetched 25 papers starting from index 1625
# Fetched 25 papers starting from index 1650
# Fetched 25 papers starting from index 1675
# Fetched 25 papers starting from index 1700
# Fetched 25 papers starting from index 1725
# Fetched 25 papers starting from index 1750
# Fetched 25 papers starting from index 1775
# Fetched 25 papers starting from index 1800
# Fetched 25 papers starting from index 1825
# Fetched 25 papers starting from index 1850
# Fetched 25 papers starting from index 1875
# Fetched 25 papers starting from index 1900
# Fetched 25 papers starting from index 1925
# Fetched 25 papers starting from index 1950
# Fetched 25 papers starting from index 1975
# Fetched 25 papers starting from index 2000
# Fetched 25 papers starting from index 2025
# Fetched 25 papers starting from index 2050
# Fetched 25 papers starting from index 2075
# Fetched 25 papers starting from index 2100
# Fetched 25 papers starting from index 2125
# Fetched 25 papers starting from index 2150
# Fetched 25 papers starting from index 2175
# Fetched 25 papers starting from index 2200
# Fetched 25 papers starting from index 2225
# Fetched 25 papers starting from index 2250
# Fetched 25 papers starting from index 2275
# Fetched 25 papers starting from index 2300
# Fetched 25 papers starting from index 2325
# Fetched 25 papers starting from index 2350
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2015_not_conference_paper_proceeding.json
# Fetching data for year 2015 with option 3
# Total results available: 2640153
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Fetched 25 papers starting from index 1375
# Fetched 25 papers starting from index 1400
# Fetched 25 papers starting from index 1425
# Fetched 25 papers starting from index 1450
# Fetched 25 papers starting from index 1475
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2015_not_conference_paper_not_proceeding.json
# Fetching data for year 2016 with option 0
# Total results available: 402864
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2016_conference_paper_proceeding.json
# Fetching data for year 2016 with option 1
# Total results available: 69694
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 25 papers starting from index 1225
# Fetched 25 papers starting from index 1250
# Fetched 25 papers starting from index 1275
# Fetched 25 papers starting from index 1300
# Fetched 25 papers starting from index 1325
# Fetched 25 papers starting from index 1350
# Total papers fetched: 1250
# Fetched 1250 papers successfully.
# Data successfully saved to 2016_conference_paper_not_proceeding.json
# Fetching data for year 2016 with option 2
# Total results available: 11485
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# ...
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 14 papers starting from index 1225
# Fetched 25 papers starting from index 1239
# Fetched 25 papers starting from index 1264
# Fetched 25 papers starting from index 1289
# Fetched 25 papers starting from index 1314
# Fetched 25 papers starting from index 1339
# Fetched 25 papers starting from index 1364
# Fetched 25 papers starting from index 1389
# Fetched 25 papers starting from index 1414
# Fetched 25 papers starting from index 1439
# Fetched 25 papers starting from index 1464
# Fetched 25 papers starting from index 1489
# Fetched 25 papers starting from index 1514
# Fetched 25 papers starting from index 1539
# Fetched 25 papers starting from index 1564
# Fetched 25 papers starting from index 1589
# Fetched 25 papers starting from index 1614
# Fetched 25 papers starting from index 1639
# Fetched 25 papers starting from index 1664
# Fetched 25 papers starting from index 1689
# Fetched 25 papers starting from index 1714
# Fetched 25 papers starting from index 1739
# Fetched 25 papers starting from index 1764
# Fetched 25 papers starting from index 1789
# Fetched 25 papers starting from index 1814
# Fetched 25 papers starting from index 1839
# Fetched 25 papers starting from index 1864
# Fetched 25 papers starting from index 1889
# Fetched 25 papers starting from index 1914
# Fetched 25 papers starting from index 1939
# Fetched 25 papers starting from index 1964
# Fetched 25 papers starting from index 1989
# Fetched 25 papers starting from index 2014
# Fetched 25 papers starting from index 2039
# Fetched 25 papers starting from index 2064
# Fetched 25 papers starting from index 2089
# Fetched 25 papers starting from index 2114
# Fetched 25 papers starting from index 2139
# Fetched 25 papers starting from index 2164
# Fetched 25 papers starting from index 2189
# Fetched 25 papers starting from index 2214
# Fetched 25 papers starting from index 2239
# Fetched 25 papers starting from index 2264
# Fetched 25 papers starting from index 2289
# Fetched 25 papers starting from index 2314
# Fetched 25 papers starting from index 2339
# Fetched 25 papers starting from index 2364
# Fetched 25 papers starting from index 2389
# Fetched 25 papers starting from index 2414
# Fetched 25 papers starting from index 2439
# Fetched 25 papers starting from index 2464
# Fetched 25 papers starting from index 2489
# Fetched 25 papers starting from index 2514
# Fetched 25 papers starting from index 2539
# Fetched 25 papers starting from index 2564
# Fetched 25 papers starting from index 2589
# Fetched 25 papers starting from index 2614
# Fetched 25 papers starting from index 2639
# Fetched 25 papers starting from index 2664
# Fetched 25 papers starting from index 2689
# Fetched 25 papers starting from index 2714
# Fetched 25 papers starting from index 2739
# Fetched 25 papers starting from index 2764
# Fetched 25 papers starting from index 2789
# Fetched 25 papers starting from index 2814
# Fetched 25 papers starting from index 2839
# Fetched 25 papers starting from index 2864
# Fetched 25 papers starting from index 2889
# Fetched 25 papers starting from index 2914
# Fetched 25 papers starting from index 2939
# Fetched 25 papers starting from index 2964
# Fetched 25 papers starting from index 2989
# Fetched 25 papers starting from index 3014
# Fetched 25 papers starting from index 3039
# Fetched 25 papers starting from index 3064
# Fetched 25 papers starting from index 3089
# Fetched 25 papers starting from index 3114
# Fetched 25 papers starting from index 3139
# Fetched 25 papers starting from index 3164
# Fetched 25 papers starting from index 3189
# Fetched 25 papers starting from index 3214
# Fetched 25 papers starting from index 3239
# Fetched 25 papers starting from index 3264
# Fetched 25 papers starting from index 3289
# Fetched 25 papers starting from index 3314
# Fetched 25 papers starting from index 3339
# Fetched 25 papers starting from index 3364
# Fetched 25 papers starting from index 3389
# Fetched 25 papers starting from index 3414
# Fetched 25 papers starting from index 3439
# Fetched 25 papers starting from index 3464
# Fetched 25 papers starting from index 3489
# Fetched 25 papers starting from index 3514
# Fetched 25 papers starting from index 3539
# Fetched 25 papers starting from index 3564
# Fetched 25 papers starting from index 3589
# Fetched 25 papers starting from index 3614
# Fetched 25 papers starting from index 3639
# Fetched 25 papers starting from index 3664
# Fetched 25 papers starting from index 3689
# Fetched 25 papers starting from index 3714
# Fetched 25 papers starting from index 3739
# Fetched 25 papers starting from index 3764
# Fetched 25 papers starting from index 3789
# Fetched 25 papers starting from index 3814
# Fetched 25 papers starting from index 3839
# Fetched 25 papers starting from index 3864
# Total papers fetched: 1239
# Fetched 1239 papers successfully.
# Data successfully saved to 2022_not_conference_paper_proceeding.json
# Fetching data for year 2023 with option 0
# Total results available: 486304
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 18 papers starting from index 1125
# Total papers fetched: 1143
# Fetched 1143 papers successfully.
# Data successfully saved to 2023_conference_paper_proceeding.json
# Fetching data for year 2023 with option 1
# Total results available: 90291
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 19 papers starting from index 1200
# Fetched 25 papers starting from index 1219
# Fetched 25 papers starting from index 1244
# Fetched 25 papers starting from index 1269
# Total papers fetched: 1219
# Fetched 1219 papers successfully.
# Data successfully saved to 2023_conference_paper_not_proceeding.json
# Fetching data for year 2023 with option 2
# Total results available: 11626
# Fetched 25 papers starting from index 0
# Fetched 25 papers starting from index 25
# Fetched 25 papers starting from index 50
# Fetched 25 papers starting from index 75
# Fetched 25 papers starting from index 100
# Fetched 25 papers starting from index 125
# Fetched 25 papers starting from index 150
# Fetched 25 papers starting from index 175
# Fetched 25 papers starting from index 200
# Fetched 25 papers starting from index 225
# Fetched 25 papers starting from index 250
# Fetched 25 papers starting from index 275
# Fetched 25 papers starting from index 300
# Fetched 25 papers starting from index 325
# Fetched 25 papers starting from index 350
# Fetched 25 papers starting from index 375
# Fetched 25 papers starting from index 400
# Fetched 25 papers starting from index 425
# Fetched 25 papers starting from index 450
# Fetched 25 papers starting from index 475
# Fetched 25 papers starting from index 500
# Fetched 25 papers starting from index 525
# Fetched 25 papers starting from index 550
# Fetched 25 papers starting from index 575
# Fetched 25 papers starting from index 600
# Fetched 25 papers starting from index 625
# Fetched 25 papers starting from index 650
# Fetched 25 papers starting from index 675
# Fetched 25 papers starting from index 700
# Fetched 25 papers starting from index 725
# Fetched 25 papers starting from index 750
# Fetched 25 papers starting from index 775
# Fetched 25 papers starting from index 800
# Fetched 25 papers starting from index 825
# Fetched 25 papers starting from index 850
# Fetched 25 papers starting from index 875
# Fetched 25 papers starting from index 900
# Fetched 25 papers starting from index 925
# Fetched 25 papers starting from index 950
# Fetched 25 papers starting from index 975
# Fetched 25 papers starting from index 1000
# Fetched 25 papers starting from index 1025
# Fetched 25 papers starting from index 1050
# Fetched 25 papers starting from index 1075
# Fetched 25 papers starting from index 1100
# Fetched 25 papers starting from index 1125
# Fetched 25 papers starting from index 1150
# Fetched 25 papers starting from index 1175
# Fetched 25 papers starting from index 1200
# Fetched 21 papers starting from index 1225
# Fetched 25 papers starting from index 1246
# Fetched 25 papers starting from index 1271
# Fetched 25 papers starting from index 1296
# Fetched 25 papers starting from index 1321
# Fetched 25 papers starting from index 1346
# Fetched 25 papers starting from index 1371
# Fetched 25 papers starting from index 1396
# Fetched 25 papers starting from index 1421
# Fetched 25 papers starting from index 1446
# Fetched 25 papers starting from index 1471
# Fetched 25 papers starting from index 1496
# Fetched 25 papers starting from index 1521
# Fetched 25 papers starting from index 1546
# Fetched 25 papers starting from index 1571
# Fetched 25 papers starting from index 1596
# Fetched 25 papers starting from index 1621
# Fetched 25 papers starting from index 1646
# Fetched 25 papers starting from index 1671
# Fetched 25 papers starting from index 1696
# Fetched 25 papers starting from index 1721
# Fetched 25 papers starting from index 1746
# Fetched 25 papers starting from index 1771
# Fetched 25 papers starting from index 1796
# Fetched 25 papers starting from index 1821
# Fetched 25 papers starting from index 1846
# Fetched 25 papers starting from index 1871
# Fetched 25 papers starting from index 1896
# Fetched 25 papers starting from index 1921
# Fetched 25 papers starting from index 1946
# Fetched 25 papers starting from index 1971
# Fetched 25 papers starting from index 1996
# Fetched 25 papers starting from index 2021
# Fetched 25 papers starting from index 2046
# Fetched 25 papers starting from index 2071
# Fetched 25 papers starting from index 2096
# Fetched 25 papers starting from index 2121
# Fetched 25 papers starting from index 2146
# Fetched 25 papers starting from index 2171
# Fetched 25 papers starting from index 2196
# Fetched 25 papers starting from index 2221
# Fetched 25 papers starting from index 2246
# Fetched 25 papers starting from index 2271
# Fetched 25 papers starting from index 2296
# Fetched 25 papers starting from index 2321
# Fetched 25 papers starting from index 2346
# Fetched 25 papers starting from index 2371
# Fetched 25 papers starting from index 2396
# Fetched 25 papers starting from index 2421
# Fetched 25 papers starting from index 2446
# Fetched 25 papers starting from index 2471
# Fetched 25 papers starting from index 2496
# Fetched 25 papers starting from index 2521
# Fetched 25 papers starting from index 2546
# Fetched 25 papers starting from index 2571
# Fetched 25 papers starting from index 2596
# Fetched 25 papers starting from index 2621
# Fetched 25 papers starting from index 2646
# Fetched 25 papers starting from index 2671
# Fetched 25 papers starting from index 2696
# Fetched 25 papers starting from index 2721
# Fetched 25 papers starting from index 2746
# Fetched 25 papers starting from index 2771
# Fetched 25 papers starting from index 2796
# Fetched 25 papers starting from index 2821
# Fetched 25 papers starting from index 2846
# Fetched 25 papers starting from index 2871
# Fetched 25 papers starting from index 2896
# Fetched 25 papers starting from index 2921
# Fetched 25 papers starting from index 2946
# Fetched 25 papers starting from index 2971
# Fetched 25 papers starting from index 2996
# Fetched 25 papers starting from index 3021
# Fetched 25 papers starting from index 3046
# Fetched 25 papers starting from index 3071
# Fetched 25 papers starting from index 3096
# Fetched 25 papers starting from index 3121
# Fetched 25 papers starting from index 3146
# Fetched 25 papers starting from index 3171
# Fetched 25 papers starting from index 3196
# Fetched 25 papers starting from index 3221
# Fetched 25 papers starting from index 3246
# Fetched 25 papers starting from index 3271
# Fetched 25 papers starting from index 3296
# Fetched 25 papers starting from index 3321
# Fetched 25 papers starting from index 3346
# Fetched 25 papers starting from index 3371
# Fetched 25 papers starting from index 3396
# Fetched 25 papers starting from index 3421
# Fetched 25 papers starting from index 3446
# Fetched 25 papers starting from index 3471
# Fetched 25 papers starting from index 3496
# Fetched 25 papers starting from index 3521
# Fetched 25 papers starting from index 3546
# Fetched 25 papers starting from index 3571
# Total papers fetched: 1246
# Fetched 1246 papers successfully.
# Data successfully saved to 2023_not_conference_paper_proceeding.json
